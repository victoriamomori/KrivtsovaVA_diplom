# %% [markdown]
# ## Парсинг

# %%
import requests
from bs4 import BeautifulSoup
import json

data = {}
url1 = 'https://lobachevskii-dml.ru/journal/kuipm'
response = requests.get(url1)
soup = BeautifulSoup(response.text, features='html.parser')
issues = soup.find_all('td')
issues_links = []
pdf_links = []
i = 0
start = -1
for issue in issues:
  while True:
    start = str(issue).find('href="', start + 1)
    if start == -1:
      break
    end = start + 6 + 39 if str(issue)[start + 6 + 39] == '"' else start + 6 + 38
    issues_links.append(str(issue)[start + 6:end])
for issue_link in issues_links:
  url2 = 'https:' + issue_link
  response = requests.get(url2)
  soup = BeautifulSoup(response.text, features='html.parser')
  articles = soup.find_all('div', class_='articleItem')
  links = []
  for article in articles:
    start = str(article).find('href="') + 6
    end = start + 39 if str(issue)[start + 35] == '"' else start + 34
    links.append(str(article)[start:end])
  print(links)
  for link in links:
    id = link[-4:]
    url = 'https:' + link
    response = requests.get(url)
    soup = BeautifulSoup(response.text, features='html.parser')
    title = soup.find_all('h3', id='title')
    authors = soup.find_all('div', id='authors')
    authors = authors[0].text.replace(u'\xa0', u' ').replace('\n', '')
    title_article = str(title[0].text.replace(u'\xa0', u' ') + ' ' + authors)
    data[str(id)] = []
    data[str(id)].append({
        'title': title_article,
        'link': link
    })
    soup = BeautifulSoup(response.text, features='html.parser')
    span = soup.find_all('span', class_='glyphicon-paperclip')
    start = str(span[0].parent).find('href="') + 6
    end = str(span[0].parent).find('>') - 13
    pdf_links.append(str(span[0].parent).replace('&amp;', '&')[start:end])
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile, indent=4, ensure_ascii=False)
# Out:
# ['//lobachevskii-dml.ru/article/9712', '//lobachevskii-dml.ru/article/9714', '//lobachevskii-dml.ru/article/9715', '//lobachevskii-dml.ru/article/9716', '//lobachevskii-dml.ru/article/9717', '//lobachevskii-dml.ru/article/9718', '//lobachevskii-dml.ru/article/9719', '//lobachevskii-dml.ru/article/9720', '//lobachevskii-dml.ru/article/9721', '//lobachevskii-dml.ru/article/9722', '//lobachevskii-dml.ru/article/9723', '//lobachevskii-dml.ru/article/9725', '//lobachevskii-dml.ru/article/9726', '//lobachevskii-dml.ru/article/9727', '//lobachevskii-dml.ru/article/9728', '//lobachevskii-dml.ru/article/9729']
# ['//lobachevskii-dml.ru/article/9700', '//lobachevskii-dml.ru/article/9701', '//lobachevskii-dml.ru/article/9703', '//lobachevskii-dml.ru/article/9704', '//lobachevskii-dml.ru/article/9705', '//lobachevskii-dml.ru/article/9706', '//lobachevskii-dml.ru/article/9707', '//lobachevskii-dml.ru/article/9708', '//lobachevskii-dml.ru/article/9709', '//lobachevskii-dml.ru/article/9710', '//lobachevskii-dml.ru/article/9711']
# ['//lobachevskii-dml.ru/article/9686', '//lobachevskii-dml.ru/article/9687', '//lobachevskii-dml.ru/article/9688', '//lobachevskii-dml.ru/article/9689', '//lobachevskii-dml.ru/article/9690', '//lobachevskii-dml.ru/article/9692', '//lobachevskii-dml.ru/article/9693', '//lobachevskii-dml.ru/article/9694', '//lobachevskii-dml.ru/article/9695', '//lobachevskii-dml.ru/article/9696', '//lobachevskii-dml.ru/article/9697', '//lobachevskii-dml.ru/article/9698', '//lobachevskii-dml.ru/article/9699']
# Link: //lobachevskii-dml.ru/article/9723
#
# Title: О корректности нелинейной двухслойной разностнойсхемы с весами А. В. Лапин
# Link: //lobachevskii-dml.ru/article/9725
#
# Title: О сходимости разностных схем для краевых задач в произвольной области А. В. Лапин
# Link: //lobachevskii-dml.ru/article/9726
#
# Title: Применение изо грамм в поискевывода Н. К. Замов, В. И. Шаронов
# Link: //lobachevskii-dml.ru/article/9727
#
# Title: Достаточные условия глобального минимума в задаче нелинейногопрограммирования Я. И. Заботин, А. И. Кораблев, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9728
#
# Title: Об абсолютном суммировании ортогональныхрядов методами Рисса В. Н. Спеваков
# Link: //lobachevskii-dml.ru/article/9729
#
# Title: О минимизации стоимости использованияпамяти с прямым доступом Р. Н. Абайдуллин
# Link: //lobachevskii-dml.ru/article/9700
#
# Title: Об автоматной моделибанка данных Р. Н. Абайдуллин, А. В. Фишер
# Link: //lobachevskii-dml.ru/article/9701
#
# Title: Динамическаямодель и имитация процесса генерации Р. Н. Абайдуллин, Т. Ф. Вахитова, Г. В. Здебская
# Link: //lobachevskii-dml.ru/article/9703
#
# Title: Организация многопультовой обучающейсистемы модульной структуры Р. Н. Абайдуллин
# Link: //lobachevskii-dml.ru/article/9704
#
# Title: Разностнаясхема для смешанной граничной задачи сильного изгиба пологихоболочек С. Н. Волошановская, М. М. Карчевский
# Link: //lobachevskii-dml.ru/article/9705
#
# Title: Собственные значения системы уравнений в гильбертовом пространстве В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9706
#
# Title: О гладкости обобщенных решений В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9707
#
# Title: Решение задачи экстраполяции для одногокласса случайных процессов Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9708
#
# Title: Задача экстраполяции по конечному интервалудля стационарного процесса частного вида Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9709
#
# Title: Некоторые свойства собственных чиселоператора Щредингера Е. А. Беговатов
# Link: //lobachevskii-dml.ru/article/9710
#
# Title: Математическая постановка и исследованиезадачи о тепловом взаимодействии потока жидкостигаза, движущегося в канале, с окружающей средой А. Н. Саламатин
# Link: //lobachevskii-dml.ru/article/9711
#
# Title: О вычислении конусов обобщенно-опорныхфункционалов Я. И. Заботин
# Link: //lobachevskii-dml.ru/article/9686
#
# Title: Об одном классе квазивогнутых функционалови задаче оптимального резервирования Я. И. Заботин
# Link: //lobachevskii-dml.ru/article/9687
#
# Title: Об одном методе для нахождения точкивыпуклого множества Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9688
#
# Title: Метод обобщенного спуска для решениязадач минимизации функционалов Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9689
#
# Title: Разрешающие тактики поискавывода в методе резолюций Н. К. Замов, В. И. Шаронов
# Link: //lobachevskii-dml.ru/article/9690
#
# Title: Принципы организации операционнойсистемы СИГМА Р. Н. Абайдуллин
# Link: //lobachevskii-dml.ru/article/9692
#
# Title: Задача регулирования потока заявок в системе коллективного пользования Р. Н. Абайдуллин
# Link: //lobachevskii-dml.ru/article/9693
#
# Title: Спектральные свойства некоторых операторныхуравнений В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9694
#
# Title: Оценки скорости сходимости разностныхсхем для одного класса вырождающихся уравнений Ю. Б. Смирнов
# Link: //lobachevskii-dml.ru/article/9695
#
# Title: Расчет давления и насыщенности приплоской фильтрации двухкомпонентных жидкостей Р. А. Александров
# Link: //lobachevskii-dml.ru/article/9696
#
# Title: Плоская фильтрация двухкомпонентныхжидкостей с учетом температуры В. А. Локотунин
# Link: //lobachevskii-dml.ru/article/9697
#
# Title: Численные расчеты давления и насыщенностис учетом капиллярных сил при вытеснении нефти водой Ю. И. Кожеватов
# Link: //lobachevskii-dml.ru/article/9698
#
# Title: О приближенном вычислении характеристическихфункционалов некоторых классов вероятностных мер А. А. Дороднов
# Link: //lobachevskii-dml.ru/article/9699
#
# Title: О предельном распределении статистики типа $x^2$ для слабозависимых наблюдений Г. Р. Абдюшева
# Link: //lobachevskii-dml.ru/article/9673
#
# Title: О случайном покрытии плоскости выпуклымифигурами Е. А. Беговатов
# Link: //lobachevskii-dml.ru/article/9674
#
# Title: О вероятности попадания нормированнойсуммы слабозависимых векторов во внешность выпуклогомножества Ф. Г. Габбасов, В. Т. Дубровин
# Link: //lobachevskii-dml.ru/article/9675
#
# Title: Исследование разностной схемыдля нелинейной стационарной задачи теории фильтрации М. М. Карчевский, А. В. Лапин
# Link: //lobachevskii-dml.ru/article/9676
#
# Title: О локальной корректности одного класса нелинейныхоператорно-разностных схем А. В. Лапин
# Link: //lobachevskii-dml.ru/article/9677
#
# Title: Цилиндрические вероятности, критерии счетнойаддитивности и носители Д. Х. Муштари
# Link: //lobachevskii-dml.ru/article/9678
#
# Title: Исследование разностных схем для квазилинейныхвырождающихся параболических уравнений Ю. Б. Смирнов
# Link: //lobachevskii-dml.ru/article/9679
#
# Title: О случайных функционалах на пространствесильно измеримых функций Ф. Ф. Султанбеков
# Link: //lobachevskii-dml.ru/article/9681
#
# Title: Вполне рандомизированные процедуры различениягипотез Е. И. Трофимов
# Link: //lobachevskii-dml.ru/article/9682
#
# Title: Об оптимальных линейных экстраполяторах некоторыхстационарных процессов Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9683
#
# Title: Об оценивании критического параметра ветвящегосяпроцесса с $n$ типами частиц Р. Х. Хайруллин
# Link: //lobachevskii-dml.ru/article/9684
#
# Title: О неизмеримых подпространствах А. Н. Чупрунов
# Link: //lobachevskii-dml.ru/article/9685
#
# Title: $\\varepsilon$-Субградиентный метод решения нелинейныхэкстремальных задач А. И. Кораблев
# Link: //lobachevskii-dml.ru/article/9654
#
# Title: Один алгоритм $\\varepsilon$-субградиентного метода минимизации и его применение А. И. Кораблев, О. В. Миронов
# Link: //lobachevskii-dml.ru/article/9655
#
# Title: Об одном методе отыскания минимакса А. И. Кораблев
# Link: //lobachevskii-dml.ru/article/9656
#
# Title: К сходимости субградиентных методов минимизациивыпуклых функций М. И. Крейнин
# Link: //lobachevskii-dml.ru/article/9657
#
# Title: О задаче идентификации точки Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9659
#
# Title: К вопросу об оптимальностиитерационных процессов С. Н. Перфилов, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9660
#
# Title: Построение конуса опорных функционаловдля многогранного множества В. Р. Фазылов
# Link: //lobachevskii-dml.ru/article/9661
#
# Title: О методах безусловной минимизации функции,использующих симплекс И. Я. Заботин
# Link: //lobachevskii-dml.ru/article/9662
#
# Title: Скорость сходимости метода возможныхнаправлений, не обязательно использующего направления наискорейшегоспуска Ю. А. Костюков
# Link: //lobachevskii-dml.ru/article/9663
#
# Title: Об оптимизации попорядку быстроты сходимости одной модификации метода Ньютона Ф. Х. Арсланов, Р. Р. Тагиров
# Link: //lobachevskii-dml.ru/article/9664
#
# Title: Оптимальный линейный интерполятор дляодного класса стационарных процессов Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9665
#
# Title: Явное экстраполирование стационарных процессовсо спектральной плотностью, обобщающей рациональную Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9666
#
# Title: Диффузионная аппроксимацияв замкнутых системах массового обслуживания Е. А. Беговатов, А. В. Лапин
# Link: //lobachevskii-dml.ru/article/9667
#
# Title: Стохастический интеграл для гауссовскихпроцессов на плоскости Е. Н. Струков
# Link: //lobachevskii-dml.ru/article/9668
#
# Title: О проверочной матрице циклического кода,порожденного кратными корнями Р. Х. Латыпов
# Link: //lobachevskii-dml.ru/article/9670
#
# Title: О влиянии формы рабочей поверхности термобурана показатели бурения льда протаиванием М. А. Пудовкин, А. Н. Саламатин, С. А. Фомин, В. К. Чистяков
# Link: //lobachevskii-dml.ru/article/9671
#
# Title: Анализ простейших математических моделейкуполовидных ледников А. Н. Саламатин
# Link: //lobachevskii-dml.ru/article/9672
#
# Title: О релаксационных методах минимизации псевдовыпуклыхфункций А. И. Кораблев
# Link: //lobachevskii-dml.ru/article/9631
#
# Title: Опыт решения модельных задачминимизации $\\varepsilin$-субградиентным методом А. И. Кораблев, О. В. Миронов
# Link: //lobachevskii-dml.ru/article/9632
#
# Title: Опорный конус для многогранника В. Р. Фазылов
# Link: //lobachevskii-dml.ru/article/9633
#
# Title: Проектирование с $\\varepsilon$-заглублением и использованиеего для решения однородных систем линейных неравенств В. Р. Фазылов
# Link: //lobachevskii-dml.ru/article/9634
#
# Title: Об одном методе для решения линейного операторногоуравнения С. Н. Перфилов
# Link: //lobachevskii-dml.ru/article/9635
#
# Title: Об итерационных методахрешения разностных схем для уравнения теплопроводности с нелинейнымиграничными условиями М. М. Карчевский, Е. М. Федотов
# Link: //lobachevskii-dml.ru/article/9637
#
# Title: Разностная схема для задачи теории упругостив сферических координатах Е. В. Стребков
# Link: //lobachevskii-dml.ru/article/9638
#
# Title: Об одной регулировке шага в итерационномпроцессе минимизации функционала Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9615
#
# Title: Об определении подходящего распределения растягивающихусилий в подвесках А. Я. Чилап
# Link: //lobachevskii-dml.ru/article/9616
#
# Title: Разностная аппроксимация “уточненной схемы сосредоточеннойемкости” А. А. Буйкис
# Link: //lobachevskii-dml.ru/article/9617
#
# Title: Процедура регуляризации микропараметрови оценка точности макрокотинуальных уравнений механики многофазныхсред А. Н. Саламатин
# Link: //lobachevskii-dml.ru/article/9618
#
# Title: Исследование распространения фильтрационныхволн давления в пластах переменной толщины М. В. Ларионов
# Link: //lobachevskii-dml.ru/article/9619
#
# Title: Диффузионная аппроксимацияв замкнутых системах массового обслуживания Е. А. Беговатов, Н. П. Евлампиев
# Link: //lobachevskii-dml.ru/article/9620
#
# Title: О случайных полях авторегрессии Г. Р. Абдюшева
# Link: //lobachevskii-dml.ru/article/9621
#
# Title: О принципах построения учебного курса «Макросредства языка Ассемблера ЕС ЭВМ» для автоматизированной обучающей системы Н. К. Замов, Н. И. Звягина, Р. К. Самитов
# Link: //lobachevskii-dml.ru/article/9622
#
# Title: Основные параметры банка данных системы «ДЕЛЬТА-У» Ш. Р. Нурутдинов
# Link: //lobachevskii-dml.ru/article/9623
#
# Title: Средства диалога в системе управления учебным процессом «ДЕЛЬТА-У» Ш. Р. Нурутдинов
# Link: //lobachevskii-dml.ru/article/9626
#
# Title: Полугруппы автоматов с двухбуквенным выходнымалфавитом Е. Л. Столов
# Link: //lobachevskii-dml.ru/article/9627
#
# Title: Решение задач управления, описываемых уравнениямис отклоняющимся аргументом В. Н. Семенова
# Link: //lobachevskii-dml.ru/article/9628
#
# Title: Об одной задаче составления расписания С. Ю. Шер
# Link: //lobachevskii-dml.ru/article/9629
#
# Title: О суммировании некоторых рядов по четвертымстепеням бесселевых функций И. Б. Айзенберг
# Link: //lobachevskii-dml.ru/article/9630
#
# Title: Оценка скорости сходимостив центральной предельной теореме для слабозависимых однородныхслучайных полей Ф. А. Аминев, В. Т. Дубровин
# Link: //lobachevskii-dml.ru/article/9577
#
# Title: Гарантийные процедуры статистического вывода
# (определение объема выборки) И. Н. Володин
# Link: //lobachevskii-dml.ru/article/9578
#
# Title: Бесконечномерный вариант теоремы Форте–Каца Л. Н. Пушкин
# Link: //lobachevskii-dml.ru/article/9579
#
# Title: Представления, веса и условные ожидания в алгебрахНеймана О. Е. Тихонов
# Link: //lobachevskii-dml.ru/article/9581
#
# Title: Программа полногокорреляционного анализа Н. И. Горбунов, И. В. Звонцова, А. Н. Хашев
# Link: //lobachevskii-dml.ru/article/9582
#
# Title: Один подход к получению численнореализуемых алгоритмов $\\varepsilon$-субградиентного метода Е. В. Анастасьев, А. И. Кораблев
# Link: //lobachevskii-dml.ru/article/9583
#
# Title: Комбинирование методов обобщенного спускаи фейеровских приближений в одном вычислительном процессе Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9584
#
# Title: Полношаговый итерационный процесс фейеровского типа для отыскания решения системы линейных неравенств С. Н. Перфилов
# Link: //lobachevskii-dml.ru/article/9585
#
# Title: Замечания о выборе параметров управленияв полношаговых итерационных процессах С. Н. Перфилов
# Link: //lobachevskii-dml.ru/article/9586
#
# Title: Метод типа условного градиента для задач негладкойоптимизации И. В. Коннов
# Link: //lobachevskii-dml.ru/article/9587
#
# Title: Алгоритмы в теории расписаний, основанные на необходимыхусловиях оптимальности А. А. Лазарев
# Link: //lobachevskii-dml.ru/article/9588
#
# Title: Двойственная задача к задаче минимизации максимальнойстоимости А. А. Лазарев
# Link: //lobachevskii-dml.ru/article/9589
#
# Title: Задача оптимизации загрузкиисполнителя при выполнении комплекса независимых работ Р. Ф. Хабибуллин, Ф. Р. Халитов
# Link: //lobachevskii-dml.ru/article/9590
#
# Title: Задача оптимального пооперационного объемногопланирования Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9592
#
# Title: Логическая система для получения правильныхобучающих программ В. Ю. Михайлов
# Link: //lobachevskii-dml.ru/article/9593
#
# Title: Исследование общей математическоймодели куполовидного ледника методами теории подобия А. Н. Саламатин, А. Б. Мазо
# Link: //lobachevskii-dml.ru/article/9594
#
# Title: О движении края покровного ледника А. Н. Саламатин
# Link: //lobachevskii-dml.ru/article/9595
#
# Title: Об одном классе механических систем с диссипацией Л. Д. Эскин
# Link: //lobachevskii-dml.ru/article/9596
#
# Title: О регуляризации нелинейной задачи теории фильтрациис разрывным законом И. Б. Бадриев
# Link: //lobachevskii-dml.ru/article/9597
#
# Title: Начальная задача для систем уравнений с линейно-преобразованным аргументом В. Н. Семенова
# Link: //lobachevskii-dml.ru/article/9598
#
# Title: Сопряженный оператор периодической задачи длялинейных дифференциальных уравнений с отклоняющимся аргументом В. Г. Никитин
# Link: //lobachevskii-dml.ru/article/9599
#
# Title: Собственные значения периодической задачи длядифференциальных уравнений с линейным отклонением аргумента И. Е. Филиппов
# Link: //lobachevskii-dml.ru/article/9600
#
# Title: О строении неограниченных мер на проекторахгильбертова пространства Г. Д. Луговая
# Link: //lobachevskii-dml.ru/article/9601
#
# Title: О приближении сплайнами некоторых стохастическихпроцессов Т. И. Качнова
# Link: //lobachevskii-dml.ru/article/9603
#
# Title: Повышение достоверности автоматизированногоконтроля параметров, изменяющихся во времени, усреднением результатовизмерений Г. М. Загрутдинов
# Link: //lobachevskii-dml.ru/article/9604
#
# Title: Применение скользящего усреднения при автоматизированномконтроле параметров, изменяющихся по синусоидальномузакону Г. М. Загрутдинов
# Link: //lobachevskii-dml.ru/article/9605
#
# Title: Повышение достоверности результатовизмерений скользящим усреднением при автоматизированномконтроле параметров, изменяющихся во времени (алгоритм и программа) Г. М. Загрутдинов, В. А. Прищепа
# Link: //lobachevskii-dml.ru/article/9606
#
# Title: Система программирования контролирующих курсов Н. К. Замов, Р. К. Самитов, П. В. Пшеничный
# Link: //lobachevskii-dml.ru/article/9522
#
# Title: Изучение свойствобучающихся элементов по программной реализации Н. Х. Насырова
# Link: //lobachevskii-dml.ru/article/9527
#
# Title: Об оперативном регулировании перевозочного процесса на автомобильном транспорте. I Р. Х. Зиятдинов
# Link: //lobachevskii-dml.ru/article/9528
#
# Title: Субградиентныйметод минимизации выпуклых функционалов и оценкиего эффективности Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9529
#
# Title: Оптимизация релаксационных процессов С. Н. Перфилов, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9530
#
# Title: Применение метода сопряженныхсубградиентов к минимизации квазивыпуклыхфункционалов И. В. Коннов
# Link: //lobachevskii-dml.ru/article/9531
#
# Title: Метод типа сопряженныхсубградиентов для минимизации функционалов И. В. Коннов
# Link: //lobachevskii-dml.ru/article/9532
#
# Title: Исследование задачтеории расписаний с помощью преобразований А. А. Лазарев
# Link: //lobachevskii-dml.ru/article/9533
#
# Title: О задаче выбора оптимальных размеровпартий Т. К. Белялов, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9534
#
# Title: Вариант работы трехслойногонефтяного пласта в оптимальном режиме А. Я. Чилап
# Link: //lobachevskii-dml.ru/article/9535
#
# Title: Системы из бесконечного числа операторных уравнений. Приложения к вычислению собственных значений некоторых задачдля дифференциальных уравнений В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9537
#
# Title: Периодическое решение неоднородногодифференциального уравнения с линейным отклонениемаргумента В. Г. Никитин
# Link: //lobachevskii-dml.ru/article/9538
#
# Title: Осцилляционные решениясистем уравнений с линейно преобразованным аргументом В. Н. Семенова
# Link: //lobachevskii-dml.ru/article/9539
#
# Title: Об однозначной разрешимости задачи Коши для одного класса дифференциально-разностных уравнений И. Е. Филиппов
# Link: //lobachevskii-dml.ru/article/9540
#
# Title: Комбинационные схемы, построенныев одноэлементном базисе Е. Л. Столов
# Link: //lobachevskii-dml.ru/article/9541
#
# Title: Вычисление характеристикразреженной марковской последовательности Н. И. Горбунов
# Link: //lobachevskii-dml.ru/article/9542
#
# Title: Корреляционная функция кусочно-стационарногопроцесса Е. А. Беговатов, Н. П. Евлампиев
# Link: //lobachevskii-dml.ru/article/9543
#
# Title: Об одной модификации параметризованного метода центров Е. А. Князев
# Link: //lobachevskii-dml.ru/article/9544
#
# Title: К теории интегральныхоператоров в пространствах измеримых вектор-функций В. Г. Наводнов
# Link: //lobachevskii-dml.ru/article/9545
#
# Title: О совершенных .пространствахкоординатного типа А. М. Сидоров
# Link: //lobachevskii-dml.ru/article/9546
#
# Title: Метод типа проекции градиента,использующий погружение допустимого множества И. Я. Заботин
# Link: //lobachevskii-dml.ru/article/9564
#
# Title: Об одном вариантеметода условного градиента И. Я. Заботин, Е. В. Лямин
# Link: //lobachevskii-dml.ru/article/9565
#
# Title: Об оптимальности двухпараметрических итерационных процессов в методе условного градиента Е. В. Лямин
# Link: //lobachevskii-dml.ru/article/9566
#
# Title: Алгоритмотыскания элемента из сопряженного конуса И. В. Коннов, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9567
# Link: //lobachevskii-dml.ru/article/9561
#
# Title: Обоснование уровня инструментальнойдостоверности автоматизированного контроля Г. М. Загрутдинов
# Link: //lobachevskii-dml.ru/article/9562
#
# Title: Эффективность систем автоматизированного контроля Г. М. Загрутдинов
# Link: //lobachevskii-dml.ru/article/9563
#
# Title: Об одном алгоритме выбора оптимальных размеров партий Т. К. Белялов, Р. Ф. Хабибуллин
# Link: //lobachevskii-dml.ru/article/9798
#
# Title: Алгоритмыс адаптацией в параметризированном методе центров Я. И. Заботин, Е. А. Князев
# Link: //lobachevskii-dml.ru/article/9799
#
# Title: К сходимости методаусловного градиента для одного класса невыпуклых функций З. Р. Габидуллина
# Link: //lobachevskii-dml.ru/article/9800
#
# Title: Релаксационныйметод решения задач условной минимизациифункции максимума Я. И. Заботин, О. А. Кашина
# Link: //lobachevskii-dml.ru/article/9801
#
# Title: Релаксационный субградиентный метод минимизации строговыпуклых функций И. Я. Заботин, М. И. Крейнин
# Link: //lobachevskii-dml.ru/article/9802
#
# Title: Вычисление с заданной точностьюсобственных значений и собственных элементов линейныхоператоров В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9803
#
# Title: Диалоговая подсистема кодирования информациидля САПР ТП сборки на базе АОС Н. И. Звягина, П. П. Морозов, А. Г. Пестов, А. А. Пузицкий, А. В. Росляков
# Link: //lobachevskii-dml.ru/article/9804
#
# Title: К теории эффекта Максвелла при больших градиентах скорости И. Б. Айзенберг
# Link: //lobachevskii-dml.ru/article/9805
#
# Title: Структураспектрального изображения, образованного дифракционной решеткой типа эшелетт Е. А. Беговатов, В. В. Куинджи, Т. С. Саамова, С. А. Стрежнев
# Link: //lobachevskii-dml.ru/article/9806
#
# Title: Построениематематической модели и разностной схемы для расчета гетерогенногопроцесса очистки гелия от водорода Р. Н. Латифуллин, Ф. Р. Муртазина, А. Н. Саламатин
# Link: //lobachevskii-dml.ru/article/9515
#
# Title: Об оценке спектральнойплотности стационарного процесса Е. А. Беговатов
# Link: //lobachevskii-dml.ru/article/9516
#
# Title: О неподвижных точках ренормгруппы Каданова Э. Ю. Лернер, М. Д. Миссаров
# Link: //lobachevskii-dml.ru/article/9517
#
# Title: Метрические свойства эргодических эндоморфизмов многомерного тора Д. А. Москвин
# Link: //lobachevskii-dml.ru/article/9518
#
# Title: Неравенства Мейера–Эмери для норм стохастических интегралов с параметром Е. И. Трофимов
# Link: //lobachevskii-dml.ru/article/9519
#
# Title: Об оценивании функционаловот решений однородных интегральных уравнений методом Монте-Карло Р. Х. Хайруллин
# Link: //lobachevskii-dml.ru/article/9520
#
# Title: О линейной фильтрациидвумерного процесса со стационарными компонентами, имеющимисовместную квазирациональную спектральную плотность Е. П. Фадеева
# Link: //lobachevskii-dml.ru/article/9521
#
# Title: Определение инструментальной достоверности контроляпри нормальных распределениях контролируемых параметрови погрешностей измерений через функции Оуэна Г. М. Загрутдинов, В. А. Прищепа
# Link: //lobachevskii-dml.ru/article/9523
#
#
# Title: Определение эффективного коэффициентатеплопроводности квазидвухмерной неоднородной структур В. А. Чугунов, О. В. Ярцев
# Link: //lobachevskii-dml.ru/article/9768
#
# Title: Математическая модель процессов тепломассообменапри контактном плавлении С. А. Фомин
# Link: //lobachevskii-dml.ru/article/9769
#
# Title: Расчет поля течений в мелком озере Н. Х. Насырова
# Link: //lobachevskii-dml.ru/article/9770
#
# Title: Об одной обратной задаче для уравненияХилла. Численные эксперименты О. А. Задворнов, Л. Д. Эскин
# Link: //lobachevskii-dml.ru/article/9771
#
# Title: О статистике процессов Гальтона–Ватсона с несколькимитипами частиц Р. Х. Хайруллин
# Link: //lobachevskii-dml.ru/article/9772
#
# Title: Минимизация негладкой строго квазивыпуклойфункции методом типа условного градиента З. Р. Габидуллина
# Link: //lobachevskii-dml.ru/article/9773
#
# Title: О минимизации функции максимума специальноговида И. Я. Заботин
# Link: //lobachevskii-dml.ru/article/9775
#
# Title: $\\varepsilon$-субрадиентные алгоритмы с адаптивным параметрическимуправлением в методе центров Е. А. Князев
# Link: //lobachevskii-dml.ru/article/9776
#
# Title: Метод случайного поиска для решениясерии задач линейного программирования А. И. Вафина, В. Р. Фазылов
# Link: //lobachevskii-dml.ru/article/9777
#
# Title: Периодические решения функционального уравненияс линейным отклонением аргумента Н. П. Евлампиев
# Link: //lobachevskii-dml.ru/article/9778
#
# Title: О собственных значениях и собственных векторахвозмущенного оператора А. М. Сидоров
# Link: //lobachevskii-dml.ru/article/9779
#
# Title: Обеспечение отказоустойчивости сетевой моделиавтомата Ш. Р. Нурутдинов
# Link: //lobachevskii-dml.ru/article/9780
#
# Title: Дедуктивный подход к автоматизации технологическогопроектирования П. В. Пшеничный
# Link: //lobachevskii-dml.ru/article/9781
#
# Title: О сходимости итерационного процесса в банаховом пространстве И. Б. Бадриев, М. М. Карчевский
# Link: //lobachevskii-dml.ru/article/9749
#
# Title: Метода штрафа и двойственности решениязадач о малых упругопластических прогибах пластин С. Н. Волошановская
# Link: //lobachevskii-dml.ru/article/9750
#
# Title: О сходимости неявной разностной схемы для задачи совместного движения грунтовых и русловых вод с произвольной формой поперечного сечения русла реки Л. Л. Глазырина, М. Ф. Павлова
# Link: //lobachevskii-dml.ru/article/9751
#
# Title: Периодическое решение линейногофункционального уравнения с переменным коэффициентом Н. П. Евлампиев, И. Е. Филиппов
# Link: //lobachevskii-dml.ru/article/9753
#
# Title: О свойствах опорных и квазиопорных векторов. И. В. Коннов
# Link: //lobachevskii-dml.ru/article/9754
#
# Title: Сходимость релаксационных методов решениязадач недифференцируемой оптимизации с ограничениями И. В. Коннов
# Link: //lobachevskii-dml.ru/article/9755
#
# Title: Алгоритм декомпозиционного типа решения задачиминимизации суммарного запаздывания А. А. Лазарев
# Link: //lobachevskii-dml.ru/article/9756
#
# Title: Математическое моделирование перистальтическогорефлекса. Численный эксперимент Р. Н. Мифтахов
# Link: //lobachevskii-dml.ru/article/9757
#
# Title: Однородные вычислительные структуры над конечным полем Ш. Р. Нурутдинов
# Link: //lobachevskii-dml.ru/article/9752
#
# Title: Один общий метод отыскания направления спуска в $\\varepsilon$-субградиентных методах А. И. Кораблев, В. В. Эйсман
# Link: //lobachevskii-dml.ru/article/9763
#
# Title: О непрерывной зависимости между произведением матриц и входящих в произведение сомножителей для конечных систем стохастических и подстохастических матриц Б. С. Кочкарев
# Link: //lobachevskii-dml.ru/article/9774
#
# Title: Расчет течения двухслойной жидкости вблизи вращающейся стенки при разгоне А. Б. Мазо, С. И. Поникаров, В. С. Гасилов, А. Н. Нестеров
# Link: //lobachevskii-dml.ru/article/9785
#
# Title: Численное обращение уравнения Абеля с неограниченной правой частью А. В. Майстер
# Link: //lobachevskii-dml.ru/article/9796
#
# Title: Метод малого параметра в случае резонанса и в отсутствии решения у вырожденного уравнения В. С. Мокейчев
# Link: //lobachevskii-dml.ru/article/9514
#
# Title: Об одном алгоритме решения граничных задач для систем уравнений с частными производными 1-го порядка с постоянными коэффициентами И. Е. Плещинская, Н. Б. Плещинский
# Link: //lobachevskii-dml.ru/article/9525
#
# Title: Решение задачи комплектовки однотипных изделий П. В. Пшеничный, Р. Р. Тагиров
# Link: //lobachevskii-dml.ru/article/9536
#
# Title: Базисность аналитически возмущенных собственных элементов А. М. Сидоров
# Link: //lobachevskii-dml.ru/article/9547
#
# Title: Быстрый прямой метод решения эрмитовых схем МКЭ четвертого порядка для уравнения Пуассона С. И. Соловьев
# Link: //lobachevskii-dml.ru/article/9558

# %% [markdown]
# ## Скачивание библиотек для считывания pdf-файлов + лемматизатор + список стоп-слов

# %%
# !pip install PyMuPDF
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.22.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 34.8 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.22.1

# %%
# !pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from PyPDF2) (4.5.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# !pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 3.2 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 58.1 MB/s eta 0:00:00
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=e160c3b9369ff64bce3d91536717e262c74cc7c942b8e9d2ce13be4160ec6cca
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from string import punctuation
punctuation

noise = stopwords.words('russian') + list(punctuation)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Функция скачивания pdf-файлов, извлечение текстовой информации и ее предобработка

# %%
import fitz

def get_pdfs(filename):
  with fitz.open(filename) as doc:
    text = ""
    for page in doc:
        text += page.get_text().lower()
  return text

import re
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize 
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def pre_process(text):
    
    # lowercase
    text=text.lower()
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W|[a-zA-Z]|[_])+"," ",text)

    #tokenize
    text = word_tokenize(text)

    #lemmatie
    for i in range(len(text)):
      text[i] = morph.parse(text[i])[0].normal_form

    #remove stop-words
    text = ' '.join(word for word in text if (not word in noise) and len(word)>3)
    
    return text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Скачивание pdf-файлов по ссылке + их предобработка

# %%
import io
import requests
from PyPDF2 import PdfReader, PdfWriter
headers = {'User-Agent': 'Mozilla/5.0 (X11; Windows; Windows x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.114 Safari/537.36'}
texts = []
for item in pdf_links: 
  url = str(item)
  response = requests.get(url=url, headers=headers, timeout=120)
  on_fly_mem_obj = io.BytesIO(response.content)
  pdf_file = PdfReader(on_fly_mem_obj)
  writer = PdfWriter()
  for pageNum in range(len(pdf_file.pages)):
    currentPage = pdf_file.pages[pageNum]
    writer.add_page(currentPage)
  outputStream = open("output.pdf","wb")
  writer.write(outputStream)
  outputStream.close()
  pdf_text = get_pdfs("output.pdf")
  pre_process_text = pre_process(pdf_text)
  texts.append(pre_process_text)
  # !rm output.pdf

# %% [markdown]
# ## Извлечение ключевых слов и формирование векторов для каждого документа

# %%
def findNumOfWords(texts):
  numOfWords = dict.fromkeys(uniqueWords, 0)
  for word in texts:
    numOfWords[word] += 1
  return numOfWords

# %%
def computeTF(text,numOfWord):
  tfDict = {}
  bagOfWordsCount = len(text)
  for word, count in numOfWord.items():
      tfDict[word] = count / float(bagOfWordsCount)
  return tfDict

# %%
def computeIDF(texts):#texts = numOfWords
    import math
    N = len(texts)
    
    idfDict = dict.fromkeys(texts[0].keys(), 0)
    for document in texts:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict

# %%
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
import nltk

for i in range(len(texts)):
  text = []
  nltk_tokens = nltk.word_tokenize(texts[i])  
  for item 	in list(nltk.bigrams(nltk_tokens)):
    token = ' '.join(item)
    text.append(token)
  texts[i] = text

uniqueWords = set(texts[0]).union(set(texts[1]))
for i in range(2, len(texts)):
  uniqueWords = (set(texts[i]).union(uniqueWords))
print(len(uniqueWords))

numOfWords = []
for i in range(len(texts)):
  numOfWords.append(findNumOfWords(texts[i]))

tf = []
for i in range(len(texts)):
  tf.append(computeTF(texts[i],numOfWords[i]))

idfs = computeIDF(numOfWords)

tfidf = []
for i in range(len(tf)):
  tfidf.append(computeTFIDF(tf[i], idfs))

for i in range(len(tfidf)):
  tfidf[i] = sorted(tfidf[i].items(), key=lambda item: item[1], reverse=True)

vector = []
for i in range(len(tfidf)):
  top_10_keyword = tfidf[i][0:10]
  keywords = {}
  keyword = []
  for k,v in top_10_keyword:
    keywords[k] = v
  for k in keywords:
    keyword.append(keywords[k])
  vector.append(keyword)
# Out:
# 128038

# %%
for i in range(len(tfidf)):
  top_10_keyword = tfidf[i][0:10]
  keywords = {}
  for k,v in top_10_keyword:
    keywords[k] = v
  print("\n===Keywords===")
  for k in keywords:
    print(k,keywords[k])
# Out:
# ===Keywords===
# конечный продукция 0.056788473945099234
# выпускать конечный 0.03785898263006616
# партия запуск 0.03324184903766019
# выпуск деталь 0.03324184903766019
# деталь производство 0.023661864143791345
# комплектный запас 0.023661864143791345
# бесперебойный работа 0.01892949131503308
# каждый деталь 0.016620924518830096
# запуск деталь 0.016620924518830096
# запуск выпуск 0.016620924518830096
#
# ===Keywords===
# функция насыщенность 0.06867567779970737
# функция давление 0.056066172315200655
# давление насыщенность 0.039424636754300836
# распределение насыщенность 0.03910720023398175
# параметр пласт 0.03154794136699935
# вычисление функция 0.027931398511224066
# скачок насыщенность 0.026071466822654505
# функция относительный 0.026071466822654505
# относительный проницаемоеть 0.026071466822654505
# зависимость распределение 0.026071466822654505
#
# ===Keywords===
# элементарный формула 0.03535663929915198
# универсально аксиоматизируемый 0.03535663929915198
# алгебраический система 0.026732724144440376
# проекция универсально 0.02651747947436399
# аксиоматизируемый класс 0.02651747947436399
# свободный переменный 0.023283511291347137
# каждый конечный 0.01767831964957599
# формула свободный 0.01767831964957599
# последовательность свойство 0.01767831964957599
# класс алгебраический 0.01767831964957599
#
# ===Keywords===
# параболический уравнение 0.05302441353615912
# разностный схема 0.049955973167218753
# схема одномерный 0.04322113891512305
# аппроксимация задача 0.032678976473146694
# метод сетка 0.02740789525215852
# сходимость разностный 0.023152261883828313
# исследование сходимость 0.022136814031170345
# действительно доказательство 0.021610569457561526
# ранее частный 0.021610569457561526
# область постоянный 0.021610569457561526
#
# ===Keywords===
# параболический уравнение 0.04910359422538679
# разностный схема 0.04626204557386807
# схема многомерный 0.040025209629145644
# корректность разностный 0.035143891456188285
# далее аналогично 0.025381255110273563
# ностный схема 0.02380982165031434
# погрешность аппроксимация 0.02380982165031434
# сходимость разностный 0.021440298857207205
# исследование сходимость 0.0204999369373162
# построить ностный 0.020012604814572822
#
# ===Keywords===
# дробно линейный 0.0842267103253795
# задача дробно 0.07194404768783141
# линейный программирование 0.06308303153220875
# целевой функция 0.0491306505501924
# знаменатель целевой 0.04796269845855427
# особый случай 0.04796269845855427
# случай табла 0.04211335516268975
# программирование особый 0.04211335516268975
# оптимальный решение 0.041590942968864696
# симплекс метод 0.03869170868076432
#
# ===Keywords===
# прогноз процесс 0.12491384104041059
# стационарный процесс 0.04823436123056151
# функция стационарный 0.039171370382878615
# спектральный характеристика 0.03665764801988031
# характеристика прогноз 0.03568966886868874
# действительный процесс 0.03568966886868874
# любой элемент 0.03269812710149969
# процесс допускать 0.031337096306302895
# пусть действительный 0.02879100457563939
# разложение волёд 0.02676725165151655
#
# ===Keywords===
# доказательство справедливый 0.041335125580644956
# задать степень 0.041335125580644956
# приблизить решение 0.035850239163206996
# определитель система 0.0312529847725003
# степень точность 0.029630122581124223
# система алгебраический 0.026211914368427968
# базис рисс 0.023895887233020444
# уравнение протяжение 0.020667562790322478
# рассмотреть дача 0.020667562790322478
# остальной промежуточный 0.020667562790322478
#
# ===Keywords===
# обобщённый решение 0.025535009167534213
# обобщённый периодический 0.024131407782476695
# быстрый некоторый 0.024131407782476695
# расти быстрый 0.024131407782476695
# множество весь 0.022105903461921806
# некоторый степень 0.020483264726898032
# вполне непрерывный 0.020483264726898032
# отображение задавать 0.019942385148556778
# отображать пространство 0.019942385148556778
# поэтому отображение 0.019942385148556778
#
# ===Keywords===
# нелинейный двухслойный 0.03902099981847296
# буняковский неравенство 0.03185382502199193
# параболический уравнение 0.029671108000020957
# квазилинейный параболический 0.029265749863854714
# корректность нелинейный 0.029265749863854714
# разностный схема 0.027954087112720283
# теорема корректность 0.026005160775986684
# направление бежать 0.024185445818462475
# многомерный параболический 0.024185445818462475
# бежать счёт 0.024185445818462475
#
# ===Keywords===
# окрестность функция 0.03158501637201731
# разностный схема 0.029698058189372815
# нелинейный двухслойный 0.021764086132929933
# двухслойный разностный 0.019339280956825543
# слагаемое сила 0.017986011921957853
# следующий слагаемое 0.017986011921957853
# параболический уравнение 0.016549154382923082
# сила условие 0.01598115602222338
# сильный норма 0.015792508186008657
# исследование корректность 0.015792508186008657
#
# ===Keywords===
# далее достигаться 0.02702400317750218
# корректность нелинейный 0.024828343747313568
# разностный схема 0.023715561268914317
# слойной разностный 0.02051833851024795
# нелинейный слойной 0.02051833851024795
# нахождение хопт 0.02051833851024795
# процесс сходиться 0.02051833851024795
# положительно опра 0.02051833851024795
# итерационный процесс 0.020303181975212414
# касательная точка 0.018016002118334786
#
# ===Keywords===
# сходимость разностный 0.05368175582887648
# число узел 0.043297585956864386
# разностный схема 0.03782201063110049
# задача произвольный 0.034647109410608855
# весь область 0.034647109410608855
# выделение пограничный 0.028632643664174718
# схема краевой 0.028632643664174718
# произвольный область 0.028632643664174718
# схема эллиптический 0.028632643664174718
# пограничный функция 0.028632643664174718
#
# ===Keywords===
# смежный точка 0.03444593798387079
# множество линия 0.03444593798387079
# точка изограмм 0.026791285098566174
# изограмм закрытый 0.022963958655913864
# закрытый часть 0.022963958655913864
# список указатель 0.022963958655913864
# содержать точка 0.019204709080358293
# развёртка цикл 0.01913663221326155
# элемент связка 0.01913663221326155
# линия изограмм 0.01913663221326155
#
# ===Keywords===
# глобальный минимум 0.03643320363678642
# пусть функционал 0.027935538381429984
# гато являться 0.027324902727589816
# производный гато 0.02611629394169603
# функционал определить 0.023103450164479778
# точка функционал 0.022043112878223907
# обобщённо опорный 0.021673042784260486
# функцио нала 0.019587220456272026
# функционал множество 0.01907390747587482
# множество линейный 0.018710674510147244
#
# ===Keywords===
# всюду являться 0.0673409925040128
# суммировать всюду 0.05387279400321025
# система суммировать 0.05387279400321025
# радемахер всюду 0.05387279400321025
# система радемахер 0.05387279400321025
# любой ортонормированный 0.04730267854766575
# ортонормированный система 0.046111614906524004
# абсолютный суммирование 0.040404595502407686
# метод рисс 0.040404595502407686
# всюду суммировать 0.040404595502407686
#
# ===Keywords===
# главный область 0.09863045149394675
# область переполнение 0.0863016450572034
# число запись 0.06164403218371672
# память прямой 0.049315225746973376
# запоминать устройство 0.049315225746973376
# средний число 0.03978279807957113
# обращение область 0.03698641931023003
# дисковый запоминать 0.03698641931023003
# запись область 0.03698641931023003
# устройство память 0.03247570013088114
#
# ===Keywords===
# банк данные 0.16602011192337
# автоматный модель 0.10713096783674102
# модель банк 0.1014924958453336
# значение атрибут 0.0841640416421017
# часть значение 0.06202319190548164
# автоматный матрица 0.05638471991407422
# атрибут заявка 0.0507462479226668
# квадратный автоматный 0.0507462479226668
# атрибут модуль 0.03946930393985195
# источник требование 0.03946930393985195
#
# ===Keywords===
# динамический модель 0.04920848283410114
# алгоритмический модель 0.0430574224798385
# процесс генерация 0.03240540640765413
# программный модель 0.03075530177131321
# оперативный память 0.01886555838745921
# магнитный лента 0.018602967126488273
# модель имитация 0.018453181062787927
# нулевой номер 0.018453181062787927
# лента нулевой 0.018453181062787927
# селекторный канал 0.018453181062787927
#
# ===Keywords===
# обучать система 0.09393465089991401
# курс обучение 0.04419245762574046
# обучение элемент 0.03006284690830564
# элемент искусственный 0.03006284690830564
# искусственный интеллект 0.03006284690830564
# тезаурус курс 0.027390745866692445
# дисковый устройство 0.027390745866692445
# этап обучение 0.024050277526644515
# обучение адаптация 0.02209622881287023
# библиотека курс 0.020543059400019333
#
# ===Keywords===
# разностный схема 0.039295066155987865
# решение разностный 0.022750494220821194
# деформация срединный 0.020998447416275916
# широта далее 0.02042031383935426
# срединный поверхность 0.020069664309874783
# сильный изгиб 0.020069664309874783
# энергия деформация 0.01843755881814804
# широта доказательство 0.016655146179037617
# граничный условие 0.016388008851273065
# теорема далее 0.014997647476470064
#
# ===Keywords===
# далее далее 0.041345906631538934
# собственный значение 0.03738584967302908
# собственный вектор 0.03075647228414117
# образовать базис 0.021763578284746694
# значение система 0.021326634986233918
# рассматривать пространство 0.021326634986233918
# система собственный 0.019966183858351326
# уравнение рассматривать 0.01821660181839321
# система уравнение 0.017908617330194557
# предположение теорема 0.017551733411005938
#
# ===Keywords===
# далее далее 0.06533260505971207
# гладкость обобщённый 0.06332679406505495
# обобщённый решение 0.03243444061391532
# порядок дифференциальный 0.03166339703252748
# исследование гладкость 0.03166339703252748
# ограничение порядок 0.02780185285113502
# размерность пространство 0.025542994310142463
# доказать свойство 0.023940308669742567
# пространство поэтому 0.023940308669742567
# функция принадлежать 0.022697169108103515
#
# ===Keywords===
# член множитель 0.035166405159875784
# неизвестный полином 0.03230918787019622
# достаточный аналитичность 0.025486904786272115
# нижний полуплоскость 0.02202324359369015
# корень полином 0.020560392281033957
# требование широта 0.018204931990194368
# соотношение достаточный 0.018204931990194368
# сгруппировать член 0.018204931990194368
# расписать выражение 0.018204931990194368
# являться целый 0.017623193383743394
#
# ===Keywords===
# фадеев задача 0.08482954876624897
# задача экстраполяция 0.06080808738663553
# экстраполирование конечный 0.042414774383124486
# кчрн дотмн 0.042414774383124486
# аврактернсягапг гкашшюго 0.042414774383124486
# спктральный таотдаспш 0.042414774383124486
# частное исслед 0.042414774383124486
# вычесть пятый 0.042414774383124486
# нетрудао найти 0.042414774383124486
# жевать полином 0.042414774383124486
#
# ===Keywords===
# функция грин 0.0683620902298457
# граница расстояние 0.05839294281512344
# гладкий граница 0.05839294281512344
# сторона основание 0.038928628543415625
# чётный образ 0.038928628543415625
# беговат некоторый 0.038928628543415625
# член асимтотик 0.038928628543415625
# свойство собственный 0.038928628543415625
# отстой граница 0.038928628543415625
# собственный число 0.035818717705504745
#
# ===Keywords===
# окружающий среда 0.04817062298507764
# поток жидкость 0.02189573772048984
# жидкость двигаться 0.021713771794990185
# движение поток 0.01628532884624264
# двигаться канал 0.01628532884624264
# постановка исследование 0.013137442632293904
# температурный поле 0.012916885097782754
# следствие решение 0.010856885897495092
# непрерывный очевидный 0.010856885897495092
# первый линия 0.010856885897495092
#
# ===Keywords===
# обобщённо опорный 0.05361929880017925
# опорный функционал 0.03861343842357345
# конус обобщённо 0.03230597065563104
# строго выпуклый 0.025403617449577767
# направление убывание 0.02400241593548404
# выпуклый множество 0.023784238549993328
# ненулевой элемент 0.023594507573681277
# запретить вариация 0.020030237065510773
# конус запретить 0.020030237065510773
# квазивыпуклый функционал 0.019727499403396274
#
# ===Keywords===
# явно квазивогнутый 0.08055467386779233
# являться явно 0.05501264268889945
# квазивогнутый функционал 0.044752596593217966
# являться вогнутый 0.03929474477778532
# оптимальный резервирование 0.03929474477778532
# квази вогнутый 0.03580207727457437
# строго квазивогнутый 0.03580207727457437
# функционал являться 0.034054849376304056
# строго вогнутый 0.03143579582222826
# задача оптимальный 0.03079126939542932
#
# ===Keywords===
# выпуклый множество 0.04342044468743038
# точка выпуклый 0.031075318698020552
# опорный конус 0.027482864840318887
# нахождение точка 0.019587920095647023
# метод фейеровский 0.01685649808334769
# фейеровский приближение 0.01685649808334769
# фейеровский направление 0.015671635387882396
# метод выбирать 0.01376038397089725
# таков метод 0.01264237356251077
# непустой ядро 0.01264237356251077
#
# ===Keywords===
# ненулевой вектор 0.03354912663380663
# содержать ненулевой 0.02616349780242438
# вектор конус 0.025161844975354973
# непустой ядро 0.019264569238111647
# конус содержать 0.017118243087834373
# опорный конус 0.015704494194467934
# иметь непустой 0.014205859976237965
# выпукло иметь 0.012580922487677487
# множество замкнуто 0.01155874154286699
# конус определённый 0.01155874154286699
#
# ===Keywords===
# метод резолюция 0.044163120236979964
# любой дизъюнкт 0.04023773286611456
# поиск вывод 0.03245994675165007
# литера предшествовать 0.03017829964958592
# содержать функциональный 0.03017829964958592
# удовлетворять тактика 0.03017829964958592
# тактика поиск 0.03017829964958592
# дизъюнкт вывод 0.03017829964958592
# тактика упорядочивание 0.03017829964958592
# вывод метод 0.03017829964958592
#
# ===Keywords===
# операционный система 0.09283628641524565
# система сигма 0.07365330152058766
# управлять программа 0.05719637593278569
# система управление 0.03548255393672042
# внутренний язык 0.0324848788807036
# многомашинный автоматизированный 0.03068887563357819
# автоматизированный система 0.02941980786908681
# принцип иерархия 0.024551100506862555
# уровень иерархия 0.024551100506862555
# управление данные 0.021556944219346594
#
# ===Keywords===
# поток заявка 0.08539602321543929
# регулирование поток 0.04744223511968849
# количество заявка 0.04744223511968849
# течение интервал 0.0379537880957508
# заявка система 0.0379537880957508
# коллективный пользование 0.037439094673956945
# система коллективный 0.037439094673956945
# число заявка 0.03332509239919022
# заявка проходить 0.028465341071813095
# проходить блок 0.028465341071813095
#
# ===Keywords===
# собственный функция 0.04477015324527432
# функция задача 0.029502571329359826
# оператор породить 0.024005065333353785
# базис рисс 0.022936715494173202
# рассмотреть оператор 0.021330585627772677
# функция состоять 0.019837974755108834
# периодический краевой 0.019837974755108834
# породить краевой 0.019837974755108834
# оценка гарантировать 0.019837974755108834
# задача образовать 0.019837974755108834
#
# ===Keywords===
# условие гладкость 0.03748769021508024
# перейти оценка 0.03465552746950638
# класс вырождаться 0.030556880469562807
# гладкость получить 0.030556880469562807
# оценка скорость 0.02945312675454023
# схема класс 0.026830282724616863
# сходиться точный 0.026830282724616863
# оценка предполагать 0.026830282724616863
# сумматорный тождество 0.02649745560113154
# разностный схема 0.025227382763015616
#
# ===Keywords===
# широта широта 0.07862653617740513
# поле давление 0.02540163818250833
# метод ричардсон 0.022072154436266724
# вычисление давление 0.019380320725354314
# вычисление насыщенность 0.017805698946293483
# давление насыщенность 0.016688487014441904
# диагональ квадрат 0.016554115827200042
# линия скважина 0.016554115827200042
# давление аналог 0.016554115827200042
# система плутон 0.016554115827200042
#
# ===Keywords===
# плоский фильтрация 0.03491091988835461
# метод разностный 0.028850658717455232
# теплообмен пласт 0.028850658717455232
# разработка пласт 0.028850658717455232
# учёт температура 0.028850658717455232
# температурный поле 0.025743614271659665
# жидкость учёт 0.025332145110551957
# значение искомый 0.023273946592236406
# давление насыщенность 0.021813631503648682
# фильтрация двухкомпонентный 0.021813631503648682
#
# ===Keywords===
# учёт капиллярный 0.22115096370967632
# капиллярный сила 0.19418025629489247
# нефть вода 0.08920170191966094
# давление насыщенность 0.06688381955204344
# насыщенность сутки 0.0663452891129029
# график насыщенность 0.0663452891129029
# сила учёт 0.0663452891129029
# сила график 0.0663452891129029
# сутки учёт 0.0663452891129029
# капиллярный давление 0.0663452891129029
#
# ===Keywords===
# выборочный функция 0.05420307680023266
# характеристический функционал 0.0475926813453013
# класс вероятностный 0.03097318674299009
# вероятностный процесс 0.023749013555875085
# функционал гаусс 0.023229890057242564
# вычисление характеристический 0.023229890057242564
# вероятностный мера 0.023031298871557467
# приблизить значение 0.021208829962455728
# функция процесс 0.021208829962455728
# взять следующий 0.020396863433700556
#
# ===Keywords===
# коэффициент перемешивание 0.07104474709173351
# предельный распределение 0.057312093483382155
# стремиться распределение 0.04736316472782234
# распределение степень 0.03552237354586676
# распределение величина 0.03243183581758855
# распределение статистика 0.031190203667367102
# степень свобода 0.031190203667367102
# набить дения 0.028656046741691078
# иметь невырожденный 0.02368158236391117
# формула упрощаться 0.02368158236391117
#
# ===Keywords===
# центр фигура 0.12445795110960617
# выпуклый фигура 0.06914330617200343
# фигура иметь 0.041485983703202056
# который накрывать 0.041485983703202056
# фигура который 0.041485983703202056
# правый полуплоскость 0.041485983703202056
# пуассоновский поле 0.041485983703202056
# круглый фигура 0.041485983703202056
# равный центр 0.02765732246880137
# накрывать вероятность 0.02765732246880137
#
# ===Keywords===
# центральный предельный 0.054814370395924315
# предельный теорема 0.0456786419966036
# вероить мета 0.040025209629145644
# внешность выпуклый 0.040025209629145644
# кибер казанский 0.040025209629145644
# мета кибер 0.040025209629145644
# многомерный центральный 0.035143891456188285
# теорема сумма 0.03228850337091953
# казанский далее 0.03228850337091953
# сумма функция 0.028691139823271698
#
# ===Keywords===
# скорость фильтрация 0.046720310332614666
# нель нейный 0.03978967968721102
# разностный схема 0.024330409153663947
# фильтрация определяться 0.02105029543458771
# оператор немыцкий 0.02105029543458771
# карчевский лапина 0.02105029543458771
# теория фильтрация 0.019368639944458126
# схема нель 0.01848308365473606
# разностный скорость 0.01848308365473606
# эллиптический уравнение 0.018253802747446174
#
# ===Keywords===
# локальный корректность 0.04642363870638363
# разностный схема 0.030661425771245115
# условие аппроксимация 0.029115709374438366
# схема локально 0.02652779354650493
# локально корректный 0.02652779354650493
# операторный разностный 0.021400081580726125
# корректность схема 0.020057341452596453
# корректный далее 0.0198958451598787
# сходимость схема 0.0198958451598787
# малый справедливый 0.0198958451598787
#
# ===Keywords===
# счётный аддитивный 0.055777353040919464
# цилиндрический вероятность 0.048577604849048564
# сепарабельный банахов 0.02242043300725318
# обобщённый случайный 0.01968612460267746
# иметь гильберт 0.018683694172710985
# гауссовский вероятность 0.01640510383556455
# гильберт носитель 0.014946955338168788
# определять счётный 0.014946955338168788
# допустимый топология 0.014946955338168788
# случайный процесс 0.013178308675822413
#
# ===Keywords===
# обобщённый решение 0.0469514684693371
# разностный схема 0.043727463455893734
# квазилинейный вырождаться 0.03577371029948915
# схема квазилинейный 0.026793330597013394
# получить следовать 0.021903988467228932
# эллиптический случай 0.020371253646375202
# показать правый 0.020371253646375202
# случай обобщённый 0.020371253646375202
# параметрически определённый 0.020371253646375202
# инта гральной 0.017886855149744574
#
# ===Keywords===
# случайный функционал 0.05447520543775094
# сравнить сравнить 0.044363593106827054
# случайный норма 0.03720237285138568
# сильно измеримый 0.036316803625167295
# случайный нормировать 0.03188774815833058
# нормировать пространство 0.02486786132978036
# вероятностный функция 0.024211202416778196
# пространство сильно 0.024211202416778196
# измеримый функция 0.016606125718195662
# иметь сравнить 0.016578574219853575
#
# ===Keywords===
# критический функция 0.07208442631746621
# объём выборка 0.03646506944666701
# условно оптимальный 0.03326973522344594
# оптимальный процедура 0.029212288312851137
# допустимый точка 0.025154841402256337
# байесовский решение 0.024343573594042614
# оперативный характеристика 0.02236569501790523
# разложение точка 0.022179823482297294
# процедура фиксировать 0.01947485887523409
# различение гипотеза 0.017892556014324185
#
# ===Keywords===
# перемена знак 0.04071003310695292
# верхний полуплоскость 0.04069620054843644
# время вперёд 0.038771396345672754
# корень функция 0.03784847791790465
# характеристика линейный 0.03154039826492054
# корень верхний 0.030532524830214687
# линейный экстраполяция 0.027693854532623397
# экстраполяция время 0.025232318611936432
# вперёд процесс 0.025232318611936432
# потеря перемена 0.025232318611936432
#
# ===Keywords===
# ветвиться процесс 0.06104816153899022
# критический параметр 0.03994256720494687
# процесс частица 0.039140647739441065
# некоторый положительный 0.03052408076949511
# параметр ветвиться 0.0293554858045808
# характеристический число 0.026970396933356306
# предположим выполнить 0.022893060577121333
# положительный характеристический 0.022288548107210517
# последовательность величина 0.022288548107210517
# совокупность соответствовать 0.022288548107210517
#
# ===Keywords===
# конечномерной подпространство 0.052808810442103025
# несчётный размерность 0.04510777593125937
# иметь несчётный 0.04510777593125937
# обобщённый случайный 0.03960660783157727
# слабо непрерывный 0.03960660783157727
# мера мера 0.03233445916590937
# иметь счётный 0.030071850620839582
# подмножество иметь 0.030071850620839582
# последовательность конечномерной 0.030071850620839582
# вероятность продолжить 0.030071850620839582
#
# ===Keywords===
# полагать идти 0.07820840048905027
# идти полагать 0.04888025030565642
# оптимальный точка 0.03909091331997999
# субградиентный метод 0.02865509055207559
# точка функционал 0.019552100122262567
# полагать выбирать 0.019552100122262567
# проекция полагать 0.019552100122262567
# направление спуск 0.018232621044450736
# обобщённо опорный 0.018022359671346674
# отыскивать условие 0.01596087181272517
#
# ===Keywords===
# полагать идти 0.11650888959252576
# идти полагать 0.06168117684310187
# субградиентный метод 0.03615938332445772
# алгоритм субградиентный 0.02569378419263851
# коэффициент отражение 0.025486904786272115
# численно реализовать 0.020560392281033957
# существовать полагать 0.01927033814447888
# оптимальный точка 0.01826969441661247
# алгоритм использоваться 0.016991269857514743
# согласующий трансформатор 0.016991269857514743
#
# ===Keywords===
# центр множество 0.050793206990114366
# безусловный оптимизация 0.03809490524258577
# кораблевый метод 0.028924070062792274
# правило точка 0.028924070062792274
# внутри множество 0.028924070062792274
# множество мочь 0.0275125055393805
# точка являться 0.02550153625435864
# являться минимизировать 0.023333167830384593
# задача максимизация 0.023333167830384593
# множество замкнуто 0.023333167830384593
#
# ===Keywords===
# поверхность уровень 0.03338372844251795
# алгоритм минимизация 0.025037796331888466
# точка минимум 0.02050813516477619
# число справедливо 0.020198094619694153
# минимизация функция 0.018708410803300525
# спуск функция 0.017947761475350578
# передвижение поверхность 0.016691864221258974
# произвольный субградиент 0.016691864221258974
# субградиент точка 0.016691864221258974
# оказываться достаточно 0.016691864221258974
#
# ===Keywords===
# задача идентификация 0.032224850829753744
# идентификация точка 0.029134138347246038
# шаговый множитель 0.022555627510864346
# общий метод 0.01807159953418464
# вырабатывать метод 0.01759014824004803
# метод вектор 0.016916720633148256
# принадлежать конус 0.016916720633148256
# метод параметр 0.014567069173623019
# последовательность вырабатывать 0.013810650355608748
# условие сходимость 0.01319261118003602
#
# ===Keywords===
# шаговый процесс 0.03809490524258577
# оптимальный процесс 0.03631045231485742
# суммарный трудоёмкость 0.031100319503088402
# функция сравнить 0.02962840758370382
# вычислительный трудоёмкость 0.02186913692732209
# процесс существовать 0.02073354633539227
# трудой кость 0.02073354633539227
# процесс иметь 0.020699309864306393
# сравнить удовлетворять 0.0198057012626495
# любой процесс 0.019444306525320493
#
# ===Keywords===
# строгий неравенство 0.11453451838508574
# неравенство группа 0.08181037027506124
# многогранный множество 0.07044730174129166
# неравенство относиться 0.05590406328529851
# неравенство строгий 0.05590406328529851
# относиться группа 0.05590406328529851
# группа определение 0.04509804077380891
# конический оболочка 0.03828019965354715
# определение соответствовать 0.037269375523532336
# вытекать вытекать 0.037269375523532336
#
# ===Keywords===
# мерный симплекс 0.03933273195390091
# линейно зависимый 0.0344161404596633
# главный точка 0.0344161404596633
# направление спуск 0.02958857878839929
# качество главный 0.02949954896542568
# линейно независимый 0.02632262289714682
# спуск точка 0.019399669299048624
# вектор линейно 0.018586874594371933
# вершина симплекс 0.017267932826224002
# использовать симплекс 0.014869499675497546
#
# ===Keywords===
# найтись неотрицательный 0.046020888804361795
# направление спуск 0.03461983510059675
# весь больший 0.033673634188790394
# неотрицательный число 0.03021688505108606
# найтись целое 0.023010444402180898
# вместо число 0.023010444402180898
# больший некоторый 0.023010444402180898
# точка алгоритм 0.023010444402180898
# спуск точка 0.020176354214755023
# стоять нуль 0.015340296268120597
#
# ===Keywords===
# метод ньютон 0.12226022115880175
# порядок быстрота 0.053117567919053095
# арслан тагир 0.053117567919053095
# быстрота сходимость 0.053117567919053095
# оптимизация порядок 0.053117567919053095
# тагир оптимизация 0.053117567919053095
# касательный гипербола 0.053117567919053095
# порядок малость 0.04663955688578258
# сходимость процесс 0.04285016335206142
# выбор параметр 0.042680221089580694
#
# ===Keywords===
# спектральный плотность 0.0425165267073471
# момент порядок 0.02970512073521959
# целый функция 0.02511594582340659
# неизвестный полином 0.02396324466204132
# оптимальный линейный 0.02396324466204132
# нижний соответственно 0.022459679823443157
# верхний полуплоскость 0.02129342432876959
# соответственно верхний 0.02129342432876959
# спечь тральный 0.02129342432876959
# спектральный плот 0.02129342432876959
#
# ===Keywords===
# спектральный плотность 0.054539852551181725
# верхний полуплоскость 0.04412428001701712
# весь прошлое 0.03603200423666957
# слагаемое функция 0.03419723085041325
# требование лемма 0.031027331452843254
# процесс спектральный 0.029416186678011415
# спектральный характеристика 0.028099785545925102
# задача экстраполяция 0.024513488898342848
# прошлое процесс 0.024021336157779717
# характеристика экстраполирование 0.02206963888650095
#
# ===Keywords===
# система массовый 0.05053602619522771
# замкнутый система 0.04643005041691719
# диффузионный аппроксимация 0.03790201964642078
# массовый обслуживание 0.030942849530920868
# возможность аппроксимация 0.028777619075132564
# неравенство гронуол 0.028777619075132564
# лапина диффузионный 0.028777619075132564
# диффузионный процесс 0.025268013097613853
# аппроксимация замкнутый 0.025268013097613853
# дифф ренциальный 0.021758407120095143
#
# ===Keywords===
# стохастический интеграл 0.08628990063594356
# гауссовский процесс 0.0528526510509576
# кривая простой 0.049137577239239325
# среднее квадратический 0.049137577239239325
# горизонтальный вертикальный 0.049137577239239325
# интеграл гауссовский 0.049137577239239325
# существование интеграл 0.04314495031797178
# существование конечный 0.04314495031797178
# конечный предел 0.03963948828821821
# предел далее 0.03715232339670425
#
# ===Keywords===
# кодовый расстояние 0.15315035301212016
# многочлен иметь 0.13613364712188458
# проверочный матрица 0.10210023534141344
# проверочный многочлен 0.08508352945117786
# циклический породить 0.08508352945117786
# корень кратность 0.07470707465237629
# иметь корень 0.06991293948701724
# циклический проверочный 0.06806682356094229
# нулевой пространство 0.05976565972190103
# двоичный циклический 0.05105011767070672
#
# ===Keywords===
# ледяной массив 0.05643741591399391
# коронка термобура 0.05538447380186681
# талый вода 0.04647787192917146
# слой талый 0.03983817593928982
# рабочий поверхность 0.03331658058917297
# поверхность плавление 0.029459487304542228
# форма коронка 0.0262347507482527
# форма рабочий 0.02331977844289129
# водный слой 0.01991908796964491
# буровой снаряд 0.017489833832168466
#
# ===Keywords===
# куполовидный ледник 0.02375406094387332
# поверхность ледник 0.02188331158245532
# институт механика 0.021475257511337574
# полосовой ледник 0.019965736887606608
# ледник характерный 0.019965736887606608
# механика ледник 0.017506649265964253
# основание ледник 0.016106443133503182
# труд институт 0.016106443133503182
# научный труд 0.016106443133503182
# ледниковый массив 0.015095850373133926
#
# ===Keywords===
# сильно квазивыпуклый 0.05929226835776716
# псевдовыпуклый функция 0.05709525902033815
# открытый выпуклый 0.028547629510169075
# квазивыпуклый функция 0.026780155836393156
# выпуклый множество 0.026727832429942998
# минимизация псевдовыпуклый 0.025528428155755192
# множество функция 0.02257715978837596
# функция сильно 0.022509226801341313
# строго псевдовыпуклый 0.022509226801341313
# пользоваться получить 0.02220397793039625
#
# ===Keywords===
# полагать идти 0.06368010387042461
# группа расчёт 0.03383083194844453
# идти полагать 0.027291473087324835
# параметр метод 0.025386294583735567
# влияние параметр 0.022553887965629685
# число субградиент 0.022553887965629685
# растяжение пространство 0.019803303915788634
# спуск растяжение 0.019803303915788634
# экспериментальный расчёт 0.019803303915788634
# полагать выбирать 0.01819431539154989
#
# ===Keywords===
# конический оболочка 0.10984976647892897
# многогранный множество 0.06931105493901275
# опорный конус 0.060284993843280135
# фазыл опорный 0.04583532070434421
# определение конический 0.04583532070434421
# неравенство конический 0.04583532070434421
# оболочка вершина 0.04024542408692529
# образовать опорный 0.04024542408692529
# ограниченность иметь 0.04024542408692529
# замкнутый ограниченный 0.030142496921640068
#
# ===Keywords===
# проектирование заглубление 0.06357238964049346
# линейный неравенство 0.054742489251194786
# последовательный проектирование 0.048672690856375496
# алгоритм последовательный 0.03620114501489606
# однородный система 0.033051552425567954
# решение однородный 0.029203614513825304
# поперечник маленький 0.024134096676597373
# заглубление использование 0.024134096676597373
# определённый однородный 0.024134096676597373
# иметь относительный 0.024134096676597373
#
# ===Keywords===
# норма ошибка 0.03061615083913335
# линейный операторный 0.02636371414858154
# система вектор 0.02636371414858154
# перфил метод 0.02324572501979011
# проекция точка 0.02293048845572619
# решение уравнение 0.021825923901540017
# положить получить 0.02138868214725437
# пусть проекция 0.020742298615611263
# конечномерной евклидов 0.0204107672260889
# показывать следующий 0.0204107672260889
#
# ===Keywords===
# решение разностный 0.056593780206196286
# разностный схема 0.052960419795947004
# кроме последовательность 0.02565950233561481
# функция построить 0.02425104631048979
# теорема кроме 0.022530169692003322
# сходиться точный 0.022530169692003322
# построить схема 0.021092943669770704
# оператор вложение 0.020699627443208
# последовательность функция 0.02033938050597543
# условие теорема 0.019994997312759995
#
# ===Keywords===
# ковариантный производная 0.06483170837268458
# сферический координата 0.06101667747280229
# разностный схема 0.049955973167218753
# аппроксимация ковариантный 0.047437572117668594
# разностный аппроксить 0.03241585418634229
# упругий тело 0.021610569457561526
# координата иметь 0.021610569457561526
# координата аппроксимация 0.021610569457561526
# упругость сферический 0.021610569457561526
# мация ковариантный 0.021610569457561526
#
# ===Keywords===
# куполовой ледник 0.03747415231212317
# ледниковый массив 0.018889166620741936
# горизонтальный основание 0.018737076156061586
# высота ледниковый 0.018737076156061586
# ледник горизонтальный 0.018737076156061586
# далее далее 0.016753146583169023
# слой время 0.01645197556080902
# профиль высота 0.015115277402210678
# разностный схема 0.014437825212064322
# сеточный функция 0.013766626027421628
#
# ===Keywords===
# горный массив 0.05048865275554667
# тепловой поток 0.049388582463332824
# плотность тепловой 0.041361846242686094
# поверхность плавление 0.040729406536413715
# коронка термобура 0.031665181388189946
# задача температурный 0.023273946592236406
# координатный поверхность 0.021637994038091427
# сплошной забой 0.021637994038091427
# рабочий поверхность 0.020680923121343047
# поверхность термобура 0.01899910883291397
#
# ===Keywords===
# любой буква 0.022963958655913864
# построить генератор 0.022963958655913864
# элемент матрица 0.01938589768212534
# являться целый 0.018525121125941707
# полный цикл 0.017222968991935397
# следовать буква 0.017222968991935397
# состояние далее 0.017222968991935397
# время полный 0.017222968991935397
# марш рута 0.017222968991935397
# любой состояние 0.017222968991935397
#
# ===Keywords===
# зависеть функция 0.0813657486974794
# константа зависеть 0.06855697711851065
# система сплайн 0.06780479058123283
# модуль гладкость 0.05424383246498626
# функция переменный 0.05357094284576594
# процесс система 0.0406828743487397
# стохастический процесс 0.0406828743487397
# сумма фурье 0.0406828743487397
# второй перо 0.030889020474666747
# дифференцировать частный 0.030889020474666747
#
# ===Keywords===
# закон композиция 0.11669185512651882
# случайный нормировать 0.060270924961095845
# случайный норма 0.048216739968876675
# функция треугольник 0.04429920269246929
# нормировать пространство 0.042302394544680724
# алгебра нейман 0.024108369984438337
# структура закон 0.020592680316444498
# замкнутый двусторонний 0.020592680316444498
# двусторонний идеал 0.020592680316444498
# идеал кольцо 0.020592680316444498
#
# ===Keywords===
# учебный курс 0.06893922692095265
# система гамма 0.04223355500885162
# обучать система 0.03964360690521795
# автоматизированный обучать 0.03342791344691025
# служебный оператор 0.031675166256638715
# язык автор 0.02877218824085156
# служебный программа 0.02819453438858043
# пользователь система 0.02427844862270503
# режим коллективный 0.02408296511584187
# автор учебный 0.023017750592681248
#
# ===Keywords===
# управлять программа 0.046087577544169464
# системный модуль 0.045005722139559695
# вывод дисплей 0.03857633326247974
# система гамма 0.03805319747121077
# ввод вывод 0.02916709551732211
# управлять блок 0.025933073974381063
# управление процесс 0.023663044276034814
# блок управление 0.022581142926600618
# служебный оператор 0.021140665261783757
# информация модуль 0.020746459179504854
#
# ===Keywords===
# работа обучать 0.053025707439105174
# модуль выдача 0.0431508225286017
# система гамма 0.03648484443009796
# обучать система 0.033824624835977715
# выдача кадр 0.03082201609185836
# анализ ответ 0.02837710122340952
# изучать кадр 0.024657612873486688
# учебный курс 0.02268777780912665
# учебный материал 0.02268777780912665
# таблица пользователь 0.022094044766293824
#
# ===Keywords===
# учебный курс 0.07165877512963059
# оператор ответ 0.040633278050678685
# язык автор 0.03640877439593012
# работа автор 0.03381848399131877
# ответ обучать 0.03006168593793594
# оператор идти 0.025395798781674177
# регистрация автор 0.022298626393113207
# помощь оператор 0.020316639025339343
# ввод учебный 0.020316639025339343
# программа регистрация 0.020316639025339343
#
# ===Keywords===
# предварительный обработка 0.09184845251740005
# обработка информация 0.0515929807354027
# сбор обработка 0.04775239629583591
# набор данные 0.046881058064116285
# собирать информация 0.04649145003958022
# система гамма 0.03821748075954365
# работа система 0.03571768153495583
# результат предварительный 0.03486858752968516
# обучать система 0.031887836501811304
# обработка собранный 0.03061615083913335
#
# ===Keywords===
# набор данные 0.09610905935561002
# значение таймер 0.0420486789198916
# запоминать информация 0.03692058633868362
# каждый кадр 0.03504056576657633
# учебный курс 0.03439068004934612
# текущий значение 0.0339208444784506
# служебный оператор 0.032261020133148674
# данные содержать 0.028032452613261066
# количество использование 0.028032452613261066
# пользователь ввести 0.028032452613261066
#
# ===Keywords===
# этап обучение 0.06574222569409113
# списочный структура 0.05378909374971093
# обучать система 0.048553527339404656
# процесс обучение 0.0404909541837681
# обучение вычисление 0.035859395833140614
# информационный модуль 0.034033411780471146
# обучение адаптация 0.027454895081859717
# задача этап 0.027226729424376917
# учебный процесс 0.025897999226291105
# разделение время 0.020585798353143905
#
# ===Keywords===
# учебный процесс 0.06742435456164507
# успеваемость посещаемость 0.04832975992634934
# управление учебный 0.03898781869617834
# обеспечивать учёт 0.028997855955809598
# банк данные 0.026474968014358002
# оперативный управление 0.023392691217707
# система дельта 0.021924925541932604
# система оперативный 0.021924925541932604
# учебный заведение 0.019856226010768502
# научный направление 0.019331903970539733
#
# ===Keywords===
# вопрос выражение 0.13065700614571682
# элементарный выражение 0.06532850307285841
# система дельта 0.05927290215474194
# статистический обработка 0.052262802458286725
# обрабатывать данные 0.052262802458286725
# начальный ввод 0.03919710184371504
# ввод идентификатор 0.03919710184371504
# абайдуллин галимов 0.026131401229143363
# определённый область 0.026131401229143363
# программа начальный 0.026131401229143363
#
# ===Keywords===
# полярный сетка 0.057701317434910464
# итерационный схема 0.04654789318447281
# упругость полярный 0.04327598807618285
# разностный схема 0.03334624604816887
# направление решение 0.029633149477999696
# менный направление 0.028850658717455232
# решение плоский 0.028850658717455232
# работа непосредственно 0.028850658717455232
# плоский теория 0.028850658717455232
# уравнение каждый 0.025332145110551957
#
# ===Keywords===
# вариационный неравенство 0.047148899441272
# решение неравенство 0.04302097057567876
# сеточный схема 0.02440012726088167
# удовлетворять вариационный 0.02227108059301991
# неравенство иметь 0.016701925598796206
# приблизить задача 0.01564398930024682
# конечный элемент 0.015250079538051043
# место оценка 0.014664406316036733
# скорость фильтрация 0.014122798689885757
# искать элемент 0.013362648355811947
#
# ===Keywords===
# неравенство корн 0.0590455341290519
# разностный схема 0.03808237954486531
# далее глушенков 0.0329482885063112
# глушенков разностный 0.0329482885063112
# анало неравенство 0.0329482885063112
# разностный анало 0.0329482885063112
# плоский задача 0.026579521615481577
# параметр выбираться 0.024911799456340814
# далее разностный 0.024785794985064915
# собственный функция 0.024785794985064915
#
# ===Keywords===
# уравнение четвёртый 0.05825407688846774
# четвёртый порядок 0.05352102115179656
# разностный схема 0.051122260478515695
# получить следовать 0.04755807612729083
# смирнов разностный 0.044230192741935265
# схема вырождаться 0.044230192741935265
# лемма погрешность 0.044230192741935265
# вырождаться уравнение 0.03344190977602172
# формула суммирование 0.029086923099481465
# гладкий решение 0.029086923099481465
#
# ===Keywords===
# направление спуск 0.06301200155500898
# хороший относительно 0.035773478377143605
# точка минимум 0.032690340812721264
# сравнить точка 0.02595803686230812
# являться минимизировать 0.023848985584762405
# пусть сравнить 0.022668109167766334
# минимум сравнить 0.022172612876483803
# спуск сравнить 0.022172612876483803
# относительно множество 0.021191895214068043
# скорый спуск 0.020277180818446976
#
# ===Keywords===
# множество бесконечно 0.032855982700843396
# метод возможный 0.030142496921640068
# доказать лемма 0.02945312675454023
# возможный направление 0.029065630852087465
# который реализовать 0.02310368497967092
# пусть подпоследовательность 0.02310368497967092
# лемма доказать 0.020493234999717874
# условие регулярность 0.020094997947760047
# лемма найтись 0.01874384510754012
# окрестность точка 0.01814187550688335
#
# ===Keywords===
# вспомогательный процедура 0.04610821251307715
# оценка процесс 0.04283633121698486
# оптимальный оценка 0.04283633121698486
# оценочный функция 0.024393046211753998
# итерационный процесс 0.021723533332276633
# применение оператор 0.02141816560849243
# являться одношаговый 0.02141816560849243
# задать погрешность 0.019677972011461684
# отыскание решение 0.018703622263961706
# суммарный трудоёмкость 0.017485587360105498
#
# ===Keywords===
# овражистость функционал 0.03758981327604948
# даваться величина 0.03758981327604948
# регулировка длина 0.03638863078309978
# коэффициент овражистость 0.03300550652631439
# способ регулировка 0.03233445916590937
# оценка число 0.026945382638257808
# больший итерация 0.02573955223618139
# предложный способ 0.022553887965629685
# длина величина 0.019803303915788634
# величина образ 0.019803303915788634
#
# ===Keywords===
# усилие стержень 0.041007069028417616
# растягивать усилие 0.02880480569569256
# усилие подвеска 0.02460424141705057
# абсолютно твёрдый 0.02460424141705057
# вертикаль угол 0.02460424141705057
# пара стержень 0.02460424141705057
# усилие равный 0.02460424141705057
# первый случай 0.017573001083540683
# треугольный пластинка 0.016402827611367046
# составлять стержень 0.016402827611367046
#
# ===Keywords===
# сосредоточить ёмкость 0.059528022903921306
# семейство разностный 0.045197453418200244
# схема сосредоточить 0.0396853486026142
# разностный схема 0.037314458798575784
# разностный аппроксимация 0.03582642371430264
# уточнить схема 0.03389809006365019
# аппроксимация уравнение 0.029764011451960653
# принцип максимум 0.025629932840271118
# условие устойчивость 0.025629932840271118
# уравнение теплопроводность 0.025629932840271118
#
# ===Keywords===
# многофазный среда 0.041587169029307425
# механика многофазный 0.034655974191089525
# процедура регуляризация 0.034655974191089525
# гетерогенный среда 0.03354854252685785
# регулярный функция 0.02795711877238154
# операция осреднение 0.027724779352871615
# регуляризовать порядок 0.027724779352871615
# макроконтинуальный уравнение 0.027724779352871615
# относительно масштаб 0.027724779352871615
# уравнение механика 0.02236569501790523
#
# ===Keywords===
# сдвиг фаза 0.05653428150535823
# толщина пласт 0.048996377304643804
# плоский линейный 0.04522742520428659
# переменный толщина 0.041458473103929375
# пласт переменный 0.03768952100357216
# схема фильтрация 0.03640235971788203
# конфигурация пласт 0.03392056890321494
# радиальный схема 0.030151616802857724
# затухание амплитуда 0.030151616802857724
# постоянный толщина 0.02638266470250051
#
# ===Keywords===
# замкнутый система 0.028085558827997383
# массовый обслуживание 0.024956458529277678
# диффузионный аппроксимация 0.022926949096992662
# аппроксимация замкнутый 0.022926949096992662
# система массовый 0.022926949096992662
# существование предел 0.02106416912099804
# обслуживание прибор 0.017407594999505917
# обслуживающий устройство 0.017407594999505917
# диффузионный аппроксить 0.017407594999505917
# требование система 0.017407594999505917
#
# ===Keywords===
# поле авторегрессия 0.059513924265326514
# случайный поле 0.05332646406943169
# степень область 0.04463544319899488
# отрицательный степень 0.04463544319899488
# случай выражаться 0.0391918789537597
# положительный степень 0.03600759800003067
# нуль единица 0.03374831470852453
# область отрицательный 0.029756962132663257
# область положительный 0.029756962132663257
# двоичный случайный 0.029756962132663257
#
# ===Keywords===
# курс макросредство 0.03468618864112534
# изучать понятие 0.029731018835250297
# язык ассемблер 0.02798149289511247
# изучение понятие 0.026105139948275864
# полный объём 0.024775849029375244
# материал порция 0.024775849029375244
# макроопределение макрокоманда 0.024775849029375244
# упражнение первый 0.024775849029375244
# изучение курс 0.019986780639366052
# задать макроопределение 0.0198206792235002
#
# ===Keywords===
# информационный блок 0.09453541193135201
# описание информационный 0.04287313218882076
# элемент данные 0.04287313218882076
# база данные 0.04200146242169671
# объём память 0.03691825950359786
# факультет количество 0.029296802924426192
# память отводить 0.029296802924426192
# сетевой структура 0.029296802924426192
# указатель память 0.029296802924426192
# информационный массив 0.023633852982838002
#
# ===Keywords===
# средство диалог 0.061444105592850615
# диалоговый язык 0.061444105592850615
# диалог система 0.057828418649899106
# ограниченный естественный 0.05120342132737551
# естественный язык 0.05120342132737551
# управление учебный 0.04956721598562781
# учебный процесс 0.045457599242544
# ключевой слово 0.041306013321356506
# диалог ограниченный 0.04096273706190041
# атрибут данные 0.04096273706190041
#
# ===Keywords===
# отношение эквивалентность 0.05184865025224661
# полугруппа автомат 0.03690636212557585
# класс отношение 0.03690636212557585
# устойчивый справа 0.029525089700460683
# относительно преобразование 0.022143817275345513
# содержать отношение 0.022143817275345513
# устойчивость отношение 0.022143817275345513
# число класс 0.019443243844592478
# пусть отношение 0.019443243844592478
# выходной алфавит 0.017863509657158074
#
# ===Keywords===
# задача управление 0.04380408298526922
# критерий управляемость 0.032853062238951916
# уравнение отклоняться 0.02346452745836935
# семёнов решение 0.02190204149263461
# точность определить 0.02190204149263461
# управление усоа 0.02190204149263461
# мерный вектор 0.0180267653750124
# задать матрица 0.01766846812589816
# отклоняться аргумент 0.01759839559377701
# задача записать 0.016559866690631177
#
# ===Keywords===
# назначение работа 0.06622815406856515
# условие допустимость 0.042145188952723275
# назначить работа 0.036124447673762806
# нижний оценка 0.03171885118715299
# допустимость графика 0.030103706394802338
# допустимый график 0.030103706394802338
# множество длительность 0.02408296511584187
# работа происходить 0.02408296511584187
# число прибор 0.018062223836881403
# работа длительность 0.018062223836881403
#
# ===Keywords===
# бесселевый функция 0.13388965476723438
# степень бесселевый 0.06931194838217905
# суммирование некоторый 0.05544955870574323
# квадрат бесселевый 0.041587169029307425
# однократный интеграл 0.041587169029307425
# четвёртый степень 0.03651536039106392
# полином лежандра 0.03651536039106392
# сумма некоторый 0.027724779352871615
# аналитический продолжение 0.027724779352871615
# операция свёртка 0.027724779352871615
#
# ===Keywords===
# центральный предельный 0.0837769535796808
# случайный поле 0.07972880342279023
# предельный теорема 0.05331260682343324
# сходимость центральный 0.048830064449889785
# предельный случайный 0.03336739589435625
# докл ссср 0.025228681445511488
# аминев дубровин 0.0222449305962375
# поле удовлетворять 0.0222449305962375
# многомерный матрица 0.0222449305962375
# лемма выполнить 0.0222449305962375
#
# ===Keywords===
# объём выборка 0.03704674857830813
# статистический эксперимент 0.03400635493545987
# вероятностный модель 0.02200549700843535
# случайный величина 0.021704306230064155
# момент остановка 0.016405093422257877
# гарантийный процедура 0.016331772031814025
# правило остановка 0.012781386807506628
# нижний граница 0.012054577352053977
# величина класс 0.01144285844438638
# измеримый пространство 0.011313899938937501
#
# ===Keywords===
# выпуклый борелевский 0.02847484853376093
# борелевский множество 0.021529486003100153
# центральный предельный 0.019498097685924982
# предельный теорема 0.019498097685924982
# вероятность применение 0.018725799690798437
# сумма определение 0.017084909120256557
# сумма незави 0.017084909120256557
# оценка скорость 0.016467780289612672
# граница множество 0.016329225871361045
# скорость сходимость 0.01534018581273087
#
# ===Keywords===
# алгебра нейман 0.11626455847333973
# сравнить сравнить 0.06398988314487036
# нормальный полуконечный 0.044717137874361435
# условный ожидание 0.044717137874361435
# точный нормальный 0.040742507292750405
# сравнить точный 0.040742507292750405
# представление алгебра 0.040742507292750405
# нормальный состояние 0.040742507292750405
# сравнить нормальный 0.040742507292750405
# нормальный представление 0.030556880469562807
#
# ===Keywords===
# частный коэффициент 0.13814256378948184
# коэффициент корреляция 0.10810611939196184
# корреляционный анализ 0.0789386078797039
# полный корреляционный 0.05920395590977793
# парный частный 0.05920395590977793
# запрос выводиться 0.05920395590977793
# корреляционный связь 0.03946930393985195
# горбунов звонцов 0.03946930393985195
# состоять пара 0.03946930393985195
# пара строка 0.03946930393985195
#
# ===Keywords===
# субградиентный метод 0.047258857033576976
# подход получение 0.03747415231212317
# реализовать алгоритм 0.03581663169146884
# переходить пункт 0.030230554804421356
# численно реализовать 0.030230554804421356
# алгоритм субградиентный 0.028333749931112904
# получение численно 0.024982768208082116
# анастасьев кораблевый 0.024982768208082116
# кораблевый подход 0.024982768208082116
# полагать переходить 0.0222922725780965
#
# ===Keywords===
# спуск фейеровский 0.03763960110820319
# комбинирование метод 0.03763960110820319
# приближение вычислительный 0.03763960110820319
# хабибуллин комбинирование 0.03763960110820319
# жество иметь 0.03304922242899825
# вычислительный процесс 0.03177489851871538
# учёт получать 0.030364023037553457
# ...
# практический точка 0.01120106061564472
# новый итерационный 0.01120106061564472
# алгоритм представлять 0.01120106061564472
# итерационный точка 0.010944004453520726
# спуск каждый 0.010498254249720172
#
# ===Keywords===
# откуда предел 0.030474958538009016
# следовательно предположение 0.030474958538009016
# некоторый номер 0.028802181006828357
# лемма функция 0.02719298665692737
# последовательность каждый 0.02675835167173585
# справедливо неравенство 0.02483950603058668
# полунепрерывный снизу 0.0241564224239869
# построение вытекать 0.022856218903506764
# определение последовательность 0.022856218903506764
# каждый опра 0.022856218903506764
#
# ===Keywords===
# опорный вектор 0.041161218299911005
# бесконечный доказательство 0.033551238295978045
# метод бесконечный 0.033551238295978045
# метод опорный 0.032479108467560136
# куликов фазыл 0.02356756829647573
# сохранять опорность 0.02356756829647573
# система выпуклый 0.02165273897837342
# бесконечный метод 0.02013074297758683
# конечный метод 0.019240339338392354
# пусть метод 0.016464487319964402
#
# ===Keywords===
# произойти условие 0.034115124653893644
# опорный вектор 0.03348240278513769
# куликов фазыл 0.02995457735161306
# положим перейти 0.025794030049332478
# вектор составной 0.022016650557841883
# метод опорный 0.022016650557841883
# итерация теорема 0.020469074792336187
# вычислять выполнение 0.020469074792336187
# перейти положим 0.020469074792336187
# таков сравнить 0.020469074792336187
#
# ===Keywords===
# температурный поле 0.03219994927947273
# рабочий поверхность 0.02217220057090928
# расчёт температурный 0.018714152974165604
# форма кулачок 0.015465523176431786
# режим источник 0.015465523176431786
# поле кулачок 0.015465523176431786
# упрочение рабочий 0.01357940839939792
# теория теплопроводность 0.01357940839939792
# боков поверхность 0.01357940839939792
# поверхность распредвал 0.01357940839939792
#
# ===Keywords===
# реперный функция 0.10472257527759715
# абсолютно вещественный 0.025387290976387186
# бесконечномерный пространство 0.01950476164570137
# сумма регулярный 0.01904046823229039
# функция регулярный 0.016718367124886887
# пусть вектор 0.01651097735949905
# индефинитный мера 0.015867056860241993
# регулярный любой 0.015867056860241993
# мера ограничить 0.015867056860241993
# пространство всякий 0.015867056860241993
#
# ===Keywords===
# промежуточный интернейрон 0.03536764012034027
# нервный волокно 0.024843472740653322
# нейронный сеть 0.015527170462908326
# нервный сеть 0.015527170462908326
# проводить путь 0.014147056048136108
# клетка осциллятор 0.014147056048136108
# расходиться путь 0.014147056048136108
# канал связь 0.013955207037772378
# проведение возбуждение 0.012421736370326661
# потенциал действие 0.012421736370326661
#
# ===Keywords===
# метод ньютон 0.07733109555069038
# модификация метод 0.04815875878349167
# ньютон решение 0.047430698055212814
# определённый условие 0.03606574334485306
# эффективность модификация 0.03441677646054301
# перфил саттар 0.03441677646054301
# решение система 0.026287873861707063
# доказываться помощь 0.01959855092185752
# рейдем неравенство 0.01959855092185752
# сгтг завершение 0.01959855092185752
#
# ===Keywords===
# автомодельный решение 0.0636302879917143
# монотонно убывать 0.04962248103237593
# чётный уравнение 0.04141041724836926
# убывать решение 0.03636016456669389
# решение уравнение 0.03332670347495103
# ледник одномерный 0.03105781293627695
# решение сток 0.03105781293627695
# неотрицательный монотонно 0.023482433913763884
# уравнение иметь 0.022652042127808275
# произвольный постоянный 0.022263070245380222
#
# ===Keywords===
# ошибка деление 0.034105439731895164
# число штрих 0.03383083194844453
# ширина щель 0.03383083194844453
# основный порядок 0.027291473087324835
# спектр решётка 0.027291473087324835
# оценка интеграл 0.027291473087324835
# порядок спектр 0.02557907979892137
# саамов стрежнев 0.02557907979892137
# спектральный изображение 0.024250844374432028
# стрежнев оценка 0.022553887965629685
#
# ===Keywords===
# подсистема грот 0.06766166389688906
# сапр селена 0.04112993890202255
# отображение маршрут 0.02602371688341887
# функция подсистема 0.022849966056679195
# телеобработка данные 0.02099344083640372
# сеть телеобработка 0.02099344083640372
# исследовательский сапр 0.02099344083640372
# изображение сеть 0.020818973506735096
# сеть передача 0.018279972845343356
# данные селена 0.016794752669122975
#
# ===Keywords===
# проектный решение 0.03651121906213286
# телеобработка данные 0.029453752539639652
# передача данные 0.023991199359716484
# процесс проектирование 0.02300473986198496
# сеть телеобработка 0.02209031440472974
# канал связь 0.0220098317993132
# параметрический проектирование 0.01825560953106643
# учебный исследовательский 0.01718135564812313
# оценка качество 0.016103317903389473
# качество функционирование 0.015213007942555356
#
# ===Keywords===
# спуск группа 0.027400204055800233
# группа переменный 0.027400204055800233
# медленный переменный 0.024852751926188923
# весь выбираться 0.022643744092982795
# метод спуск 0.021400823736149356
# быстрый медленный 0.01988220154095114
# подмножество индекс 0.01826680270386682
# производиться спуск 0.014911651155713355
# условие справедливый 0.014911651155713355
# размерность подпространство 0.014911651155713355
#
# ===Keywords===
# выбрать условие 0.03042454346335389
# трудоёмкость метод 0.029164865766888717
# оценка трудоёмкость 0.026455466590289488
# метод выбрать 0.02380991993126054
# большой итерация 0.023403494971810688
# следовать переход 0.02184352374321449
# общий схема 0.01851882661320264
# итерация большой 0.017863509657158074
# параметр метод 0.01661648372753601
# итерация метод 0.015368157610657435
#
# ===Keywords===
# задать цикл 0.049480209783925144
# линейный функция 0.0431004986814472
# цикл состояние 0.04241160838622156
# двоичный набор 0.03220158508407185
# набор цикл 0.03220158508407185
# длина цикл 0.02827440559081437
# первый разряд 0.02415118881305389
# проход алгоритм 0.02415118881305389
# цикл разрядный 0.02415118881305389
# свободный цикл 0.02415118881305389
#
# ===Keywords===
# свободный поверхность 0.01541314969548763
# течение ледник 0.013618715283179919
# временной слой 0.01301261185956559
# мазо численный 0.012764214077877596
# центр элемент 0.011254613400670656
# устойчивый лишь 0.011254613400670656
# ледниковый купол 0.011254613400670656
# узловой значение 0.011254613400670656
# метод ньютон 0.011101988965198125
# поверхность ледник 0.011101988965198125
#
# ===Keywords===
# обратный задача 0.036515996138709435
# удельный баланс 0.03194899223289844
# баланс масса 0.02935318488265411
# балансовый кривая 0.02555919378631875
# горнодолинный ледник 0.02555919378631875
# прямой задача 0.02348254790612329
# горный ледник 0.021831932524988534
# распределение удельный 0.019169395339739062
# решение обратный 0.017611910929592467
# языковой часть 0.014554621683325688
#
# ===Keywords===
# уравнение абель 0.07521492655208457
# кубический сплайн 0.03760746327604229
# майстер приближение 0.034975875491314964
# функция приближать 0.034975875491314964
# приближать решение 0.034975875491314964
# докторский осипов 0.030710354380176837
# приближение ломаный 0.028215184484126597
# обращение уравнение 0.02507164218402819
# откуда сила 0.02300104380482073
# мочь записать 0.01968414226185035
#
# ===Keywords===
# объект удовлетворять 0.04411575498581124
# спектральный пара 0.03868222114652904
# базис рисс 0.034004496709343454
# аналитически зависеть 0.030208178251828924
# ограничить постоянный 0.02941050332387416
# объект зависеть 0.02205787749290562
# группа предположение 0.02205787749290562
# предположение теорема 0.02125281044333966
# собственный значение 0.01980531104929548
# постоянный независящий 0.019367784942220193
#
# ===Keywords===
# корреляционный функция 0.06870658247722226
# производный процесс 0.047641361210298196
# случайный процесс 0.04185842854161134
# стационарный случайный 0.033282627112195345
# действительный число 0.029170466741560246
# исходный производный 0.02712925903264287
# связать меаду 0.02712925903264287
# никитин чубак 0.02712925903264287
# меаду соотношение 0.02712925903264287
# функция исходный 0.02712925903264287
#
# ===Keywords===
# коэффициент фурье 0.022783228744879928
# достаточно выполняться 0.018549433408138662
# уравнение необходимо 0.018549433408138662
# действительный число 0.017586223834120493
# смысл функционал 0.016355625229751602
# частность любой 0.016355625229751602
# даваться равенство 0.016355625229751602
# решение уравнение 0.015356657248709448
# уравнение вольтерра 0.014360957084255355
# равенство функционал 0.014360957084255355
#
# ===Keywords===
# уравнение вольтерра 0.06309742351099551
# интегральный уравнение 0.05870011768035531
# вырожденный ядро 0.05162516469081451
# решение уравнение 0.035050498482276086
# вольтерра вырожденный 0.03441677646054301
# решение интегральный 0.025777031850230128
# матрица функция 0.02108031024676125
# часть уравнение 0.02052089356025153
# сингулярный интегральный 0.019757634051580646
# структура решение 0.019757634051580646
#
# ===Keywords===
# аналог ядро 0.05502130746172807
# автоморфный аналог 0.049519176715555266
# сингулярный интегральный 0.037903289139746776
# метод механический 0.031331751749386336
# интегральный уравнение 0.029634481739632748
# линейный преобразование 0.02506540139950907
# группа дробно 0.02506540139950907
# квадратурный формула 0.023689555712341732
# дробно линейный 0.02200852298469123
# механический квадратура 0.018799051049631803
#
# ===Keywords===
# голоморфный решение 0.042414774383124486
# сингулярный интегральный 0.04008661759532454
# сагит аналитичность 0.027931525672269045
# аналитичность параметр 0.027931525672269045
# оператор породить 0.02566213141046962
# резонансный случай 0.02566213141046962
# интегральный уравнение 0.02507320423306614
# индукционный предположение 0.022803032769988324
# неизвестный вектор 0.021207387191562243
# известный вектор 0.021207387191562243
#
# ===Keywords===
# спектральный пара 0.06343303529723733
# пара оператор 0.04064564280011098
# элемент число 0.02659361524089152
# собственный значение 0.022841485178821945
# иметь геометрический 0.019544775144042046
# выполнение оценка 0.019544775144042046
# геометрический кратность 0.019544775144042046
# сидоров аналитичность 0.019544775144042046
# кратность равный 0.0179567916919213
# пусть собственный 0.0179567916919213
#
# ===Keywords===
# перестановочный вести 0.04059699833813344
# переходной вероятность 0.029101013249318436
# цепь марков 0.029101013249318436
# серия класс 0.027064665558755627
# обозначить вести 0.027064665558755627
# иметь замечать 0.027064665558755627
# обозначать линейный 0.027064665558755627
# являться симметричный 0.027064665558755627
# схема серия 0.027064665558755627
# марков переходной 0.027064665558755627
#
# ===Keywords===
# асимптотический мощность 0.056134121158900555
# алнй критерий 0.04210059086917542
# корень уравнение 0.028750528840482965
# мощность алнй 0.028067060579450277
# критерий проверка 0.028067060579450277
# параметрический несостоятельность 0.028067060579450277
# функция мощность 0.028067060579450277
# исследование асимптотический 0.028067060579450277
# уравнение справедливо 0.028067060579450277
# мощность критерий 0.028067060579450277
#
# ===Keywords===
# мера пуассон 0.05231061411717753
# кодовость язык 0.041848491293742025
# сильно непрерывный 0.03138636847030652
# главный диагональ 0.02383052313349552
# диагональ который 0.02383052313349552
# непрерывный сжимать 0.02383052313349552
# который стоять 0.02383052313349552
# диагональный матрица 0.02383052313349552
# пуассоновский случайный 0.02383052313349552
# матрица главный 0.02383052313349552
#
# ===Keywords===
# система булев 0.046283222861064184
# кодовость язык 0.04063870184673238
# фильтрационный консолидация 0.04063870184673238
# бесконечный язык 0.03733686871881574
# булев матрица 0.03702657828885134
# кодовость бесконечный 0.032510961477385907
# кодовый язык 0.027769933716638506
# определять кодовый 0.027769933716638506
# свойство кодовость 0.024383221108039425
# язык являться 0.024383221108039425
#
# ===Keywords===
# фильтрационный консолидация 0.03705766772360447
# классический решение 0.03404678820794979
# сильный выпуклость 0.0308813897696704
# вариация функционал 0.02813653350167664
# выпуклость функционал 0.024705111815736317
# эквивалентный задача 0.020332206030571235
# пространство вектор 0.020169019083686044
# сильно выпуклый 0.019266437119359537
# обобщённый решение 0.018013558447394187
# норма пространство 0.017842268443855672
#
# ===Keywords===
# фиктивный область 0.03747508826116698
# пусть выполнить 0.03330929458631722
# метод фиктивный 0.031229240217639148
# выполнить условие 0.021879333236899112
# задача изгиб 0.020396204530185636
# изгиб пологий 0.01873754413058349
# слабо полунепрерывный 0.01871173776362137
# полунепрерывный снизу 0.018043245184775198
# задача иметь 0.01642357100780126
# градиент функционал 0.01613498900958244
#
# ===Keywords===
# следовать переход 0.021806707224523735
# система матрица 0.020057341452596453
# аффинный оболочка 0.0198958451598787
# сопрячь конус 0.019015831294770504
# отыскание направление 0.018164855533771885
# замечание алгоритм 0.01746942562466302
# проекция нуль 0.016050061185544594
# направление спуск 0.013303927296534259
# аффинный независимо 0.013263896773252465
# определяться решение 0.013263896773252465
#
# ===Keywords===
# система матрица 0.08299478252353888
# подстохастический матрица 0.05354541402123107
# стохастический матрица 0.03935594402292337
# система стохастический 0.03748178981486175
# любой система 0.032127248412738646
# система подстохастический 0.030491307764692496
# непосредственно устанавливаться 0.024393046211753998
# матрица устойчивый 0.024393046211753998
# существовать эффективный 0.024393046211753998
# матрица удовлетворять 0.023054106256538576
#
# ===Keywords===
# граница раздел 0.028894623084429652
# пограничный слой 0.027601562397947706
# новый приближение 0.024185445818462475
# однородный жидкость 0.024185445818462475
# межфазный граница 0.024185445818462475
# находиться новый 0.024185445818462475
# развитие течение 0.024185445818462475
# уравнение находиться 0.021235883347994623
# двухслойный жидкость 0.021235883347994623
# течение двухслойный 0.021235883347994623
#
# ===Keywords===
# уравнение абель 0.05263749166543386
# обращение уравнение 0.04210999333234709
# майстер численный 0.025790349285678225
# неограниченный правый 0.025790349285678225
# абель неограниченный 0.025790349285678225
# интеграл мочь 0.025790349285678225
# казан технол 0.025790349285678225
# численный обращение 0.025790349285678225
# технол казань 0.025790349285678225
# казань ниитэхий 0.025790349285678225
#
# ===Keywords===
# голоморфный зависеть 0.06686564432163154
# полиномиальный подчинить 0.02507461662061183
# случай резонанс 0.02359909731668677
# решение уравнение 0.019058708549737624
# параметр случай 0.01895861208625937
# метод малое 0.01895861208625937
# оператор полиномиальный 0.018347178627863
# нормально разрешимый 0.01685649808334769
# малое параметр 0.01648971890419133
# ненулевой решение 0.0146777429022904
#
# ===Keywords===
# потенциальный уравнение 0.045924226258700025
# собственный значение 0.03689845746103407
# граничный задача 0.03679455273256152
# комплексно сопрячь 0.026789131984241682
# потенциальный функция 0.026151440647263872
# решение система 0.023384918465935732
# инвариантный подпространство 0.021792867206053227
# значение матрица 0.019347367775776014
# производная порядок 0.018746051479622307
# решение граничный 0.017580396774043605
#
# ===Keywords===
# задача комплектовка 0.03304922242899825
# отношение согласованность 0.02509306740546879
# число комплект 0.02509306740546879
# независимый множество 0.0220328149526655
# однотипный изделие 0.0220328149526655
# показать задача 0.020985278134166348
# элемент комплект 0.02091088950455733
# являться полный 0.015810468749885176
# вершина граф 0.014989484381547392
# задача граф 0.014688543301777001
#
# ===Keywords===
# базис рисс 0.06419632227343415
# спектральный пара 0.0464719135488163
# аналитически зависеть 0.03456323532957927
# собственный элемент 0.03319422396344021
# являться базис 0.0300265956868973
# последовательность являться 0.027696540052194893
# эрмитовый схема 0.026592003126707297
# значит следовательно 0.022898501276476683
# выполнить условие 0.02258238302119476
# пара оператор 0.020737941197747568
#
# ===Keywords===
# уравнение пуассон 0.04119015115038681
# матрица размер 0.0409265276782742
# эрмитовый схема 0.038022343518314176
# собственный значение 0.03332681456567164
# схема четвёртый 0.028516757638735634
# корень уравнение 0.02772372423903715
# четвёртый порядок 0.026199814163831842
# метод фурье 0.024555916606964517
# размер соответственно 0.0216517324470045
# предположение невырожденность 0.0216517324470045

# %% [markdown]
# ## Добавление векторов для каждого документа в json-файл

# %%
id = []
with open('data.txt') as json_file:
  data = json.load(json_file)
  for item in data:
    id.append(item)

# %%
def add_to_json(id, vector_article):
    json_data = {
        "vector": vector_article
    }
    data = json.load(open("data.txt"))
    data[str(id)].append(json_data)
    with open("data.txt", "w") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

i = 0
for item in id:
  add_to_json(item, vector[i])
  i+=1

# %% [markdown]
# ## Вычисление косинусного расстояния между документами

# %%
import math

def cosine_sim(vec1, vec2):
    dot_prod = 0
    for i, v in enumerate(vec1):
        dot_prod += v * vec2[i]
        
    mag_1 = math.sqrt(sum([x**2 for x in vec1]))
    mag_2 = math.sqrt(sum([x**2 for x in vec2]))
    
    return dot_prod / (mag_1 * mag_2)

# %%
from scipy.spatial import distance

id = '9716';
with open('data.txt') as json_file:
  data = json.load(json_file)
  p = data[str(id)][1]
  query_features = p['vector']
  
  distances = {}
  sorted_dict = {}
  
  for item in data:
    p = data[str(item)][1]
    distances[str(item)] = math.degrees(math.acos(cosine_sim(query_features, p['vector'])))
  sorted_tuples = sorted(distances.items(), key=lambda item: item[1], reverse=False)
  sorted_dict = {k: v for k, v in sorted_tuples}
  print(sorted_dict)
  
  keys = []
  for key in sorted_dict:
    keys.append(key)

  query_doc = data[id][0]['title']
  print("Document:\n %s \n" %(query_doc))
  print("Most similar to previous document:")
  for i in range(1, 6):
    key = str(keys[i])
    return_doc = data[str(key)][0]['title']
    print(' ' + return_doc)
# Out:
# {'9716': 0.0, '9634': 2.520234803989072, '9679': 2.579308743707877, '9793': 2.8092917886136557, '9717': 3.231398102370205, '9759': 3.4080810119303586, '9780': 3.581714059317853, '9605': 3.7929818193411156, '9784': 3.959593761554169, '9752': 4.071242551816685, '9587': 4.174519774596043, '9713': 4.283988828511238, '9803': 4.398224476199799, '9689': 4.58459720674623, '9614': 4.608776717065929, '9706': 4.672460522801116, '9522': 4.787048884592248, '9671': 4.961442399365427, '9702': 4.99653175369922, '9525': 5.086006454687383, '9703': 5.107157574280605, '9651': 5.176106966277392, '9700': 5.275119311998568, '9516': 5.304756276071145, '9750': 5.342058722699566, '9640': 5.343785455864619, '9673': 5.354376936310951, '9601': 5.449998804976109, '9670': 5.462301017220725, '9659': 5.723801323810773, '9519': 5.812801347163513, '9806': 5.820564028809742, '9756': 5.891220492925429, '9627': 5.922885204958885, '9669': 5.947629842292017, '9645': 6.020056670412681, '9523': 6.049315248264965, '9714': 6.117181693441533, '9625': 6.196493769165168, '9638': 6.205121067257718, '9642': 6.246985486848158, '9570': 6.257136584053391, '9646': 6.343678684346497, '9563': 6.355673891164621, '9801': 6.384487639152343, '9799': 6.432580148170904, '9660': 6.469455735639365, '9546': 6.477906134449823, '9741': 6.527905580046016, '9551': 6.53605795015853, '9708': 6.540938544245706, '9748': 6.546257752887689, '9607': 6.556849576230504, '9737': 6.657629106340976, '9667': 6.67280163303613, '9718': 6.738355648908859, '9578': 6.8783607531601465, '9681': 6.919583080105721, '